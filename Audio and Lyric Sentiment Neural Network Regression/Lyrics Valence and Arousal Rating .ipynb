# %%
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer

import csv
import numpy as np

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text


# turn a doc into clean tokens
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens


# load doc, clean and return line of tokens
def doc_to_line(filename):
    # load the doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    return ' '.join(tokens)


# load all docs in a directory and place data in a list
def read_docs(directory):
    lines = list()
    filenames = listdir(directory)
    filenames.sort()
    
#     print(filenames)
    # walk through all files in the folder
    for filename in filenames:
        # create the full path of the file to open
        path = directory + '/' + filename
        print(path)
        # load and clean the doc
        line = doc_to_line(path)
        # add to list
        lines.append(line)
    return lines


lines = read_docs('MER_bimodal_dataset/Lyrics_Dump')
wva = np.load('rated_words.npy')
print(wva[:,1])

print("# of Lyrics:",len(lines))
# print(lines[1])
max_words_per_line = len(lines[0].split())
for i in range(1,len(lines)):
    line = lines[i].split()
    if(len(line) > max_words_per_line):
        max_words_per_line = len(line)
print('maximum number of words per line: ',max_words_per_line)
# Out:
# MER_bimodal_dataset/Lyrics_Dump/L001.txt
# MER_bimodal_dataset/Lyrics_Dump/L002.txt
# MER_bimodal_dataset/Lyrics_Dump/L004.txt
# MER_bimodal_dataset/Lyrics_Dump/L005.txt
# MER_bimodal_dataset/Lyrics_Dump/L006.txt
# MER_bimodal_dataset/Lyrics_Dump/L007.txt
# MER_bimodal_dataset/Lyrics_Dump/L008.txt
# MER_bimodal_dataset/Lyrics_Dump/L009.txt
# MER_bimodal_dataset/Lyrics_Dump/L010.txt
# MER_bimodal_dataset/Lyrics_Dump/L011.txt
# MER_bimodal_dataset/Lyrics_Dump/L012.txt
# MER_bimodal_dataset/Lyrics_Dump/L013.txt
# MER_bimodal_dataset/Lyrics_Dump/L014.txt
# MER_bimodal_dataset/Lyrics_Dump/L015.txt
# MER_bimodal_dataset/Lyrics_Dump/L016.txt
# MER_bimodal_dataset/Lyrics_Dump/L017.txt
# MER_bimodal_dataset/Lyrics_Dump/L018.txt
# MER_bimodal_dataset/Lyrics_Dump/L020.txt
# MER_bimodal_dataset/Lyrics_Dump/L021.txt
# MER_bimodal_dataset/Lyrics_Dump/L022.txt
# MER_bimodal_dataset/Lyrics_Dump/L024.txt
# MER_bimodal_dataset/Lyrics_Dump/L025.txt
# MER_bimodal_dataset/Lyrics_Dump/L026.txt
# MER_bimodal_dataset/Lyrics_Dump/L027.txt
# MER_bimodal_dataset/Lyrics_Dump/L028.txt
# MER_bimodal_dataset/Lyrics_Dump/L030.txt
# MER_bimodal_dataset/Lyrics_Dump/L031.txt
# MER_bimodal_dataset/Lyrics_Dump/L032.txt
# MER_bimodal_dataset/Lyrics_Dump/L033.txt
# MER_bimodal_dataset/Lyrics_Dump/L034.txt
# MER_bimodal_dataset/Lyrics_Dump/L035.txt
# MER_bimodal_dataset/Lyrics_Dump/L036.txt
# MER_bimodal_dataset/Lyrics_Dump/L037.txt
# MER_bimodal_dataset/Lyrics_Dump/L038.txt
# MER_bimodal_dataset/Lyrics_Dump/L040.txt
# MER_bimodal_dataset/Lyrics_Dump/L041.txt
# MER_bimodal_dataset/Lyrics_Dump/L042.txt
# MER_bimodal_dataset/Lyrics_Dump/L043.txt
# MER_bimodal_dataset/Lyrics_Dump/L044.txt
# MER_bimodal_dataset/Lyrics_Dump/L045.txt
# MER_bimodal_dataset/Lyrics_Dump/L046.txt
# MER_bimodal_dataset/Lyrics_Dump/L047.txt
# MER_bimodal_dataset/Lyrics_Dump/L048.txt
# MER_bimodal_dataset/Lyrics_Dump/L049.txt
# MER_bimodal_dataset/Lyrics_Dump/L050.txt
# MER_bimodal_dataset/Lyrics_Dump/L051.txt
# MER_bimodal_dataset/Lyrics_Dump/L052.txt
# MER_bimodal_dataset/Lyrics_Dump/L053.txt
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-59-3fe72be2d031> in <module>()
#      64
#      65
# ---> 66 lines = read_docs('MER_bimodal_dataset/Lyrics_Dump')
#      67 wva = np.load('rated_words.npy')
#      68 print(wva[:,1])
#
# <ipython-input-59-3fe72be2d031> in read_docs(directory)
#      58         print(path)
#      59         # load and clean the doc
# ---> 60         line = doc_to_line(path)
#      61         # add to list
#      62         lines.append(line)
#
# <ipython-input-59-3fe72be2d031> in doc_to_line(filename)
#      39 def doc_to_line(filename):
#      40     # load the doc
# ---> 41     doc = load_doc(filename)
#      42     # clean doc
#      43     tokens = clean_doc(doc)
#
# <ipython-input-59-3fe72be2d031> in load_doc(filename)
#      13     file = open(filename, 'r')
#      14     # read all text
# ---> 15     text = file.read()
#      16     # close the file
#      17     file.close()
#
# ~/Envs/work/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x91 in position 409: invalid start byte

# %%
for i in range(3):
    print(wva[:,i])
# Out:
# ['aardvark' 'abalone' 'abandon' ... 'zoo' 'zoom' 'zucchini']
# ['6.26' '5.3' '2.84' ... '7' '5.86' '6.3']
# ['2.41' '2.65' '3.73' ... '5.63' '5.68' '4.18']

# %%
average_valence = []
average_arousal = []
for i in range(5): # len(lines)
    line = lines[i].split()
    sum_valence = 0
    sum_arousal = 0
    no_of_matched_words = 0
    for x in range(len(line)):
        if(line[x] in wva[:,0]):
            no_of_matched_words+=1
            sum_valence += float(wva[x][1])
            sum_arousal += float(wva[x][2])
            print("lyric",i+1,"word valence:",wva[x][1])
            print("lyric",i+1,"word arousal:",wva[x][2])
    print("average valence:", sum_valence/no_of_matched_words)
    print("average arousal:", sum_arousal/no_of_matched_words)
    average_valence.append(sum_valence/no_of_matched_words)
    average_arousal.append(sum_arousal/no_of_matched_words)
    if(len(line) > max_words_per_line):
        max_words_per_line = len(line)
print('maximum number of words per line: ',max_words_per_line)
# lyric 2 word valence: 4.48
# lyric 2 word arousal: 3.5
# lyric 2 word valence: 7
# lyric 2 word arousal: 4.85
# lyric 2 word valence: 3.05
# lyric 2 word arousal: 5
# lyric 2 word valence: 5.28
# lyric 2 word arousal: 2.9
# lyric 2 word valence: 4.05
# lyric 2 word arousal: 5.45
# lyric 2 word valence: 2.5
# lyric 2 word arousal: 5.9
# lyric 2 word valence: 5.11
# lyric 2 word arousal: 5.27
# lyric 2 word valence: 4.26
# lyric 2 word arousal: 6.1
# lyric 2 word valence: 4.62
# lyric 2 word arousal: 4.61
# lyric 2 word valence: 2.79
# lyric 2 word arousal: 4
# lyric 2 word valence: 1.53
# lyric 2 word arousal: 6.21
# lyric 2 word valence: 6.19
# lyric 2 word arousal: 6.73
# lyric 2 word valence: 5.63
# lyric 2 word arousal: 5
# lyric 2 word valence: 6.68
# lyric 2 word arousal: 5.3
# lyric 2 word valence: 6.68
# lyric 2 word arousal: 3.2
# lyric 2 word valence: 6.35
# lyric 2 word arousal: 3
# lyric 2 word valence: 5.47
# lyric 2 word arousal: 3.85
# lyric 2 word valence: 7.45
# lyric 2 word arousal: 5.16
# lyric 2 word valence: 4.42
# lyric 2 word arousal: 3.68
# lyric 2 word valence: 7.42
# lyric 2 word arousal: 4.35
# lyric 2 word valence: 3.21
# lyric 2 word arousal: 5.33
# lyric 2 word valence: 6.37
# lyric 2 word arousal: 4.64
# lyric 2 word valence: 6.53
# lyric 2 word arousal: 3.3
# lyric 2 word valence: 2.18
# lyric 2 word arousal: 4.47
# lyric 2 word valence: 5.6
# lyric 2 word arousal: 4.56
# lyric 2 word valence: 5.53
# lyric 2 word arousal: 2.73
# lyric 2 word valence: 6
# lyric 2 word arousal: 4.9
# lyric 2 word valence: 5.52
# lyric 2 word arousal: 3.73
# lyric 2 word valence: 5.7
# lyric 2 word arousal: 3.78
# lyric 2 word valence: 6.21
# lyric 2 word arousal: 4.86
# lyric 2 word valence: 4.81
# lyric 2 word arousal: 4.9
# lyric 2 word valence: 5.1
# lyric 2 word arousal: 5.09
# lyric 2 word valence: 4.11
# lyric 2 word arousal: 3.33
# lyric 2 word valence: 5.84
# lyric 2 word arousal: 3.9
# lyric 2 word valence: 5.82
# lyric 2 word arousal: 3.55
# lyric 2 word valence: 6.11
# lyric 2 word arousal: 3.05
# lyric 2 word valence: 4.7
# lyric 2 word arousal: 3.64
# average valence: 5.09675
# average arousal: 4.347
# lyric 3 word valence: 5.3
# lyric 3 word arousal: 2.65
# lyric 3 word valence: 2.84
# lyric 3 word arousal: 3.73
# lyric 3 word valence: 2.63
# lyric 3 word arousal: 4.95
# lyric 3 word valence: 2.42
# lyric 3 word arousal: 5.9
# lyric 3 word valence: 2.05
# lyric 3 word arousal: 5.33
# lyric 3 word valence: 7
# lyric 3 word arousal: 4.85
# lyric 3 word valence: 4
# lyric 3 word arousal: 3.94
# lyric 3 word valence: 6.64
# lyric 3 word arousal: 3.24
# lyric 3 word valence: 3.52
# lyric 3 word arousal: 4.48
# lyric 3 word valence: 3.52
# lyric 3 word arousal: 4.82
# lyric 3 word valence: 6.14
# lyric 3 word arousal: 4.17
# lyric 3 word valence: 4.7
# lyric 3 word arousal: 3.64
# lyric 3 word valence: 4.79
# lyric 3 word arousal: 3.21
# lyric 3 word valence: 7
# lyric 3 word arousal: 4.57
# lyric 3 word valence: 7.58
# lyric 3 word arousal: 5.52
# lyric 3 word valence: 7.05
# lyric 3 word arousal: 6
# lyric 3 word valence: 5.56
# lyric 3 word arousal: 3.35
# lyric 3 word valence: 5.25
# lyric 3 word arousal: 3.89
# lyric 3 word valence: 6.9
# lyric 3 word arousal: 4.71
# lyric 3 word valence: 7.4
# lyric 3 word arousal: 4.66
# lyric 3 word valence: 6.47
# lyric 3 word arousal: 4.36
# lyric 3 word valence: 7.38
# lyric 3 word arousal: 4.86
# average valence: 5.249850746268656
# average arousal: 4.311194029850745
# lyric 4 word valence: 2.84
# lyric 4 word arousal: 3.73
# lyric 4 word valence: 5.85
# lyric 4 word arousal: 2.2
# lyric 4 word valence: 2.42
# lyric 4 word arousal: 5.9
# lyric 4 word valence: 2.05
# lyric 4 word arousal: 5.33
# lyric 4 word valence: 5.57
# lyric 4 word arousal: 3.59
# lyric 4 word valence: 4
# lyric 4 word arousal: 3.94
# lyric 4 word valence: 3.53
# lyric 4 word arousal: 4.48
# lyric 4 word valence: 3.05
# lyric 4 word arousal: 5
# lyric 4 word valence: 4.05
# lyric 4 word arousal: 5.45
# lyric 4 word valence: 2.58
# lyric 4 word arousal: 5.43
# lyric 4 word valence: 5.11
# lyric 4 word arousal: 5.27
# lyric 4 word valence: 3.28
# lyric 4 word arousal: 5.23
# lyric 4 word valence: 4.1
# lyric 4 word arousal: 3.72
# lyric 4 word valence: 3.53
# lyric 4 word arousal: 3.7
# lyric 4 word valence: 4.58
# lyric 4 word arousal: 3.53
# lyric 4 word valence: 5.5
# lyric 4 word arousal: 4.27
# lyric 4 word valence: 4.4
# lyric 4 word arousal: 3.1
# lyric 4 word valence: 4.45
# lyric 4 word arousal: 4.02
# lyric 4 word valence: 4.06
# lyric 4 word arousal: 4.7
# lyric 4 word valence: 3.45
# lyric 4 word arousal: 3.91
# lyric 4 word valence: 6.61
# lyric 4 word arousal: 3.32
# lyric 4 word valence: 4.59
# lyric 4 word arousal: 4.81
# lyric 4 word valence: 6.21
# lyric 4 word arousal: 4.75
# lyric 4 word valence: 6.68
# lyric 4 word arousal: 5.3
# lyric 4 word valence: 6.68
# lyric 4 word arousal: 3.2
# lyric 4 word valence: 3.46
# lyric 4 word arousal: 4
# lyric 4 word valence: 6.35
# lyric 4 word arousal: 3
# lyric 4 word valence: 6.76
# lyric 4 word arousal: 4.72
# lyric 4 word valence: 5.47
# lyric 4 word arousal: 3.85
# lyric 4 word valence: 7.45
# lyric 4 word arousal: 5.16
# lyric 4 word valence: 8.05
# lyric 4 word arousal: 4.96
# lyric 4 word valence: 5.7
# lyric 4 word arousal: 4.2
# lyric 4 word valence: 6.33
# lyric 4 word arousal: 2.73
# lyric 4 word valence: 6.32
# lyric 4 word arousal: 3.33
# lyric 4 word valence: 3.38
# lyric 4 word arousal: 5.48
# lyric 4 word valence: 4.11
# lyric 4 word arousal: 3.67
# lyric 4 word valence: 3.27
# lyric 4 word arousal: 4.3
# lyric 4 word valence: 3.15
# lyric 4 word arousal: 4.48
# lyric 4 word valence: 6.43
# lyric 4 word arousal: 3.26
# lyric 4 word valence: 6.53
# lyric 4 word arousal: 3.3
# lyric 4 word valence: 2.18
# lyric 4 word arousal: 4.47
# lyric 4 word valence: 7.1
# lyric 4 word arousal: 4
# lyric 4 word valence: 6.33
# lyric 4 word arousal: 3.19
# lyric 4 word valence: 6.19
# lyric 4 word arousal: 4.95
# lyric 4 word valence: 6
# lyric 4 word arousal: 4.9
# lyric 4 word valence: 5.52
# lyric 4 word arousal: 3.73
# lyric 4 word valence: 6.18
# lyric 4 word arousal: 4.65
# lyric 4 word valence: 6.47
# lyric 4 word arousal: 5.62
# lyric 4 word valence: 6.24
# lyric 4 word arousal: 5.26
# lyric 4 word valence: 5.42
# lyric 4 word arousal: 5.43
# lyric 4 word valence: 6.22
# lyric 4 word arousal: 2.75
# lyric 4 word valence: 4.81
# lyric 4 word arousal: 4.9
# lyric 4 word valence: 5.1
# lyric 4 word arousal: 5.09
# lyric 4 word valence: 4.11
# lyric 4 word arousal: 3.33
# lyric 4 word valence: 5.84
# lyric 4 word arousal: 3.9
# lyric 4 word valence: 5.82
# lyric 4 word arousal: 3.55
# lyric 4 word valence: 2.86
# lyric 4 word arousal: 5.33
# lyric 4 word valence: 2.89
# lyric 4 word arousal: 4.77
# lyric 4 word valence: 3.52
# lyric 4 word arousal: 4.82
# lyric 4 word valence: 6.15
# lyric 4 word arousal: 3.61
# lyric 4 word valence: 6.11
# lyric 4 word arousal: 3.05
# lyric 4 word valence: 4.7
# lyric 4 word arousal: 3.64
# lyric 4 word valence: 5.15
# lyric 4 word arousal: 2.78
# lyric 4 word valence: 5.06
# lyric 4 word arousal: 3.52
# lyric 4 word valence: 5.53
# lyric 4 word arousal: 4.59
# lyric 4 word valence: 5.32
# lyric 4 word arousal: 4.74
# lyric 4 word valence: 6.16
# lyric 4 word arousal: 4.27
# lyric 4 word valence: 7.58
# lyric 4 word arousal: 5.52
# lyric 4 word valence: 7.05
# lyric 4 word arousal: 6
# lyric 4 word valence: 5.56
# lyric 4 word arousal: 3.35
# lyric 4 word valence: 6.29
# lyric 4 word arousal: 3.6
# lyric 4 word valence: 6
# lyric 4 word arousal: 5.1
# lyric 4 word valence: 6.9
# lyric 4 word arousal: 4.71
# lyric 4 word valence: 6.68
# lyric 4 word arousal: 4.82
# lyric 4 word valence: 5.67
# lyric 4 word arousal: 4.4
# lyric 4 word valence: 7.37
# lyric 4 word arousal: 5.96
# lyric 4 word valence: 5.05
# lyric 4 word arousal: 4.28
# lyric 4 word valence: 7.47
# lyric 4 word arousal: 5.81
# lyric 4 word valence: 6.71
# lyric 4 word arousal: 3.95
# lyric 4 word valence: 7
# lyric 4 word arousal: 5.27
# lyric 4 word valence: 3.68
# lyric 4 word arousal: 3.89
# lyric 4 word valence: 4.26
# lyric 4 word arousal: 3.82
# lyric 4 word valence: 4.3
# lyric 4 word arousal: 4.14
# lyric 4 word valence: 5.62
# lyric 4 word arousal: 4.36
# lyric 4 word valence: 5.44
# lyric 4 word arousal: 3.38
# lyric 4 word valence: 4.74
# lyric 4 word arousal: 3.19
# lyric 4 word valence: 5.25
# lyric 4 word arousal: 4.59
# lyric 4 word valence: 6
# lyric 4 word arousal: 5.1
# lyric 4 word valence: 5.79
# lyric 4 word arousal: 4.52
# lyric 4 word valence: 3.1
# lyric 4 word arousal: 5.4
# lyric 4 word valence: 5.65
# lyric 4 word arousal: 3.61
# lyric 4 word valence: 5.32
# lyric 4 word arousal: 3.9
# lyric 4 word valence: 5.95
# lyric 4 word arousal: 3.95
# lyric 4 word valence: 5.94
# lyric 4 word arousal: 3.64
# lyric 4 word valence: 7.52
# lyric 4 word arousal: 4.11
# lyric 4 word valence: 4.53
# lyric 4 word arousal: 4.5
# lyric 4 word valence: 6.05
# lyric 4 word arousal: 5.41
# lyric 4 word valence: 5.57
# lyric 4 word arousal: 4.13
# lyric 4 word valence: 2.25
# lyric 4 word arousal: 5.12
# lyric 4 word valence: 6.42
# lyric 4 word arousal: 4.11
# lyric 4 word valence: 5.53
# lyric 4 word arousal: 4.32
# lyric 4 word valence: 4.29
# lyric 4 word arousal: 5.38
# lyric 4 word valence: 5.05
# lyric 4 word arousal: 3.62
# lyric 4 word valence: 2.55
# lyric 4 word arousal: 5.9
# lyric 4 word valence: 2.48
# lyric 4 word arousal: 5.35
# lyric 4 word valence: 3.18
# lyric 4 word arousal: 5.69
# lyric 4 word valence: 2.8
# lyric 4 word arousal: 6.55
# average valence: 5.135514018691587
# average arousal: 4.370186915887849
# lyric 5 word valence: 5.3
# lyric 5 word arousal: 2.65
# lyric 5 word valence: 5.52
# lyric 5 word arousal: 3.26
# lyric 5 word valence: 5.15
# lyric 5 word arousal: 6.75
# lyric 5 word valence: 3.05
# lyric 5 word arousal: 5
# lyric 5 word valence: 5.28
# lyric 5 word arousal: 2.9
# lyric 5 word valence: 4.05
# lyric 5 word arousal: 5.45
# lyric 5 word valence: 3.1
# lyric 5 word arousal: 5.8
# lyric 5 word valence: 4.62
# lyric 5 word arousal: 4.61
# lyric 5 word valence: 3.28
# lyric 5 word arousal: 5.23
# lyric 5 word valence: 4.1
# lyric 5 word arousal: 3.72
# lyric 5 word valence: 6.58
# lyric 5 word arousal: 3.38
# lyric 5 word valence: 4.58
# lyric 5 word arousal: 3.53
# lyric 5 word valence: 3.43
# lyric 5 word arousal: 3.15
# lyric 5 word valence: 4.45
# lyric 5 word arousal: 4.02
# lyric 5 word valence: 4.06
# lyric 5 word arousal: 4.7
# lyric 5 word valence: 3.9
# lyric 5 word arousal: 4.85
# lyric 5 word valence: 6.61
# lyric 5 word arousal: 3.32
# lyric 5 word valence: 4.59
# lyric 5 word arousal: 4.81
# lyric 5 word valence: 6.21
# lyric 5 word arousal: 4.75
# lyric 5 word valence: 6.48
# lyric 5 word arousal: 4.95
# lyric 5 word valence: 6.39
# lyric 5 word arousal: 2.8
# lyric 5 word valence: 6.84
# lyric 5 word arousal: 4.3
# lyric 5 word valence: 6.68
# lyric 5 word arousal: 3.2
# lyric 5 word valence: 6.1
# lyric 5 word arousal: 3.95
# lyric 5 word valence: 6.35
# lyric 5 word arousal: 3
# lyric 5 word valence: 4.6
# lyric 5 word arousal: 4.5
# lyric 5 word valence: 6.38
# lyric 5 word arousal: 2.85
# lyric 5 word valence: 5.26
# lyric 5 word arousal: 2.94
# average valence: 5.104999999999999
# average arousal: 4.084642857142857
# maximum number of words per line:  750

# %%
lyrics = []
for i in range(1,len(lines)):
    lyrics.append(lines[i].split())
print(lyrics[0])
a = np.array([lyrics[0],average_valence[0],average_arousal[0]])
b = np.array([lyrics[1],average_valence[1],average_arousal[1]])
rated_lyrics = np.vstack((a,b))
print(rated_lyrics[1][0])
# Out:
# ['plopped', 'easy', 'chair', 'turned', 'Channel', 'bad', 'gunslinger', 'called', 'Salty', 'Sam', 'chasin', 'poor', 'Sweet', 'Sue', 'He', 'trapped', 'old', 'sawmill', 'said', 'evil', 'laugh', 'If', 'dont', 'give', 'deed', 'ranch', 'Ill', 'saw', 'half', 'And', 'grabbed', 'He', 'tied', 'He', 'turned', 'bandsaw', 'Chorus', 'And', 'along', 'came', 'Jones', 'Tall', 'thin', 'Jones', 'Slowwalkin', 'Jones', 'Slowtalkin', 'Jones', 'Along', 'came', 'long', 'lean', 'lanky', 'Jones', 'Commercial', 'came', 'got', 'get', 'snack', 'You', 'shouldve', 'seen', 'goin', 'time', 'got', 'back', 'Down', 'old', 'abandoned', 'mine', 'Sweet', 'Sue', 'havin', 'fits', 'That', 'villain', 'said', 'Give', 'deed', 'ranch', 'Or', 'Ill', 'blow', 'bits', 'And', 'grabbed', 'He', 'tied', 'He', 'lit', 'fuse', 'dynamite', 'Chorus', 'got', 'bugged', 'turned', 'turned', 'another', 'show', 'But', 'old', 'shootemup', 'old', 'rodeo', 'Salty', 'Sam', 'tryin', 'stuff', 'Sweet', 'Sue', 'burlap', 'sack', 'He', 'said', 'If', 'dont', 'give', 'deed', 'ranch', 'Im', 'gonna', 'throw', 'railroad', 'tracks', 'And', 'grabbed', 'He', 'tied', 'He', 'threw', 'railroad', 'tracks', 'train', 'started', 'comin', 'Chorus']

# %%
# Out:
# 4.2126829268292685
