# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import csv
import pandas as pd
print(tf.__version__)
# Out:
# 1.10.0

# %%
# LOAD DATA
x_train = np.load("train_x.npy")
arousal_y_train = np.load("arousal_train_y.npy")
x_test = np.load("test_x.npy")
arousal_y_test = np.load("arousal_test_y.npy")

arousal_y_train = arousal_y_train.flatten()
arousal_y_test = arousal_y_test.flatten()

# Shuffle the training set
order = np.argsort(np.random.random(arousal_y_train.shape))
x_train = x_train[order]
arousal_y_train = arousal_y_train[order]

print("training set: {}".format(x_train.shape))
print("arousal_y_train: {}".format(arousal_y_train.shape))
print("testing set: {}".format(x_test.shape))
print("arousal_y_test: {}".format(arousal_y_test.shape))
# Out:
# training set: (1351, 193)
# arousal_y_train: (1351,)
# testing set: (451, 193)
# arousal_y_test: (451,)

# %%
# Normalize the data

print(x_train[0][1], type(x_train[0][1]))  # Display sample features, notice the different scales

# Using mean and standard deviation
# mean = x_train.mean(axis=0)
# std = x_train.std(axis=0)
# x_train = (x_train - mean) / std
# x_test = (x_test - mean) / std

# Using keras utilities normalize
x_train = tf.keras.utils.normalize(x_train, axis=1)  # scales data between 0 and 1
x_test = tf.keras.utils.normalize(x_test, axis=1)  # scales data between 0 and 1

print(x_train[0][1], type(x_train[0][1]))
# Out:
# 149.47476416535162 <class 'numpy.float64'>
# 0.40206796977878806 <class 'numpy.float64'>

# %%
def build_model():
  model = keras.Sequential([
    keras.layers.Dense(64, activation=tf.nn.relu, 
                       input_shape=(x_train.shape[1],)),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(1)
  ])

  optimizer = tf.train.RMSPropOptimizer(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae'])
  return model

model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 16,641
# Trainable params: 16,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Display training progress by printing a single dot for each completed epoch.
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

# Store training stats
history = model.fit(x_train, arousal_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
import matplotlib.pyplot as plt


def plot_history(history):
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Arousal]')
  plt.plot(history.epoch, np.array(history.history['mean_absolute_error']), 
           label='Train Loss')
  plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
           label = 'Val loss')
  plt.legend()
  plt.ylim([0,5])

# %%
plot_history(history)

# %%
model = build_model()

# The patience parameter is the amount of epochs to check for improvement.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(x_train, arousal_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# .......................................

# %%
[loss, mae] = model.evaluate(x_test, arousal_y_test, verbose=0)

print("Testing set Mean Abs Error:{:7.2f}".format(mae))
# Out:
# Testing set Mean Abs Error:   0.72

# %%
test_predictions = model.predict(x_test).flatten()

print(len(test_predictions))
print(len(arousal_y_test))
# Out:
# 451
# 451

# %%
less_than_one=0
less_than_two=0
less_than_three=0
not_manageable=0

for i in range(len(arousal_y_test)):
    diff = abs(test_predictions[i] - arousal_y_test[i])
    if(diff < 1):
        less_than_one = less_than_one + 1
    elif(diff < 2):
        less_than_two = less_than_two + 1
    elif(diff < 3):
        less_than_three = less_than_three + 1
    else:
        not_manageable = not_manageable + 1
    print("test[{0:}] - expected: {1:.1f}, prediction: {2:.1f}".format(i,test_predictions[i],arousal_y_test[i]))
print("Differences\nLess than one: {}\nLess than two: {}\nLess than three: {}".format(less_than_one,less_than_two,less_than_three))

# print("test[{}] - values different by {:.1f}".format(i,diff))
# print("test[436] - expected: {0:.1f}, prediction: {1:.1f}".format(test_predictions[436],arousal_y_test[436]))
# Out:
# test[0] - expected: 6.5, prediction: 7.0
# test[1] - expected: 6.3, prediction: 6.5
# test[2] - expected: 4.2, prediction: 4.1
# test[3] - expected: 5.4, prediction: 6.2
# test[4] - expected: 4.5, prediction: 3.1
# test[5] - expected: 5.5, prediction: 6.6
# test[6] - expected: 4.3, prediction: 4.6
# test[7] - expected: 4.7, prediction: 4.6
# test[8] - expected: 5.6, prediction: 5.5
# test[9] - expected: 4.7, prediction: 5.9
# test[10] - expected: 5.7, prediction: 3.9
# test[11] - expected: 6.1, prediction: 5.3
# test[12] - expected: 5.8, prediction: 5.7
# test[13] - expected: 4.9, prediction: 6.0
# test[14] - expected: 5.0, prediction: 5.9
# test[15] - expected: 5.1, prediction: 5.3
# test[16] - expected: 5.5, prediction: 6.4
# test[17] - expected: 4.7, prediction: 4.4
# test[18] - expected: 6.3, prediction: 6.0
# test[19] - expected: 4.7, prediction: 3.9
# test[20] - expected: 4.4, prediction: 4.8
# test[21] - expected: 4.8, prediction: 6.3
# test[22] - expected: 5.3, prediction: 5.4
# test[23] - expected: 5.2, prediction: 4.8
# test[24] - expected: 4.2, prediction: 3.4
# test[25] - expected: 6.0, prediction: 6.3
# test[26] - expected: 5.5, prediction: 6.1
# test[27] - expected: 5.5, prediction: 6.1
# test[28] - expected: 5.4, prediction: 5.2
# test[29] - expected: 4.6, prediction: 3.6
# test[30] - expected: 4.8, prediction: 3.9
# test[31] - expected: 5.2, prediction: 5.3
# test[32] - expected: 5.6, prediction: 6.1
# test[33] - expected: 5.7, prediction: 5.3
# test[34] - expected: 4.6, prediction: 4.9
# test[35] - expected: 4.9, prediction: 4.3
# test[36] - expected: 5.1, prediction: 5.9
# test[37] - expected: 4.9, prediction: 5.7
# test[38] - expected: 4.2, prediction: 3.7
# test[39] - expected: 5.5, prediction: 5.8
# test[40] - expected: 3.2, prediction: 2.5
# test[41] - expected: 5.0, prediction: 6.0
# test[42] - expected: 4.6, prediction: 4.7
# test[43] - expected: 5.3, prediction: 6.0
# test[44] - expected: 6.3, prediction: 6.3
# test[45] - expected: 4.3, prediction: 3.1
# test[46] - expected: 4.4, prediction: 3.1
# test[47] - expected: 5.3, prediction: 6.1
# test[48] - expected: 4.2, prediction: 4.0
# test[49] - expected: 5.3, prediction: 5.7
# test[50] - expected: 4.3, prediction: 5.9
# test[51] - expected: 5.3, prediction: 4.6
# test[52] - expected: 4.5, prediction: 5.5
# test[53] - expected: 6.3, prediction: 6.3
# test[54] - expected: 6.2, prediction: 6.0
# test[55] - expected: 4.4, prediction: 4.9
# test[56] - expected: 4.2, prediction: 4.0
# test[57] - expected: 5.5, prediction: 5.7
# test[58] - expected: 4.5, prediction: 3.3
# test[59] - expected: 6.4, prediction: 7.5
# test[60] - expected: 4.8, prediction: 5.5
# test[61] - expected: 4.3, prediction: 4.9
# test[62] - expected: 5.0, prediction: 5.4
# test[63] - expected: 4.0, prediction: 3.3
# test[64] - expected: 3.9, prediction: 2.6
# test[65] - expected: 5.6, prediction: 5.9
# test[66] - expected: 5.6, prediction: 5.3
# test[67] - expected: 6.0, prediction: 5.7
# test[68] - expected: 5.2, prediction: 4.9
# test[69] - expected: 5.0, prediction: 6.4
# test[70] - expected: 5.0, prediction: 4.2
# test[71] - expected: 5.0, prediction: 5.6
# test[72] - expected: 5.5, prediction: 6.1
# test[73] - expected: 4.6, prediction: 3.5
# test[74] - expected: 6.0, prediction: 5.8
# test[75] - expected: 4.9, prediction: 4.8
# test[76] - expected: 5.7, prediction: 5.0
# test[77] - expected: 4.7, prediction: 4.5
# test[78] - expected: 4.3, prediction: 3.3
# test[79] - expected: 5.5, prediction: 4.7
# test[80] - expected: 6.1, prediction: 4.7
# test[81] - expected: 5.6, prediction: 6.4
# test[82] - expected: 4.6, prediction: 4.6
# test[83] - expected: 4.5, prediction: 3.6
# test[84] - expected: 4.1, prediction: 3.3
# test[85] - expected: 4.0, prediction: 3.8
# test[86] - expected: 5.9, prediction: 6.1
# test[87] - expected: 4.5, prediction: 5.6
# test[88] - expected: 4.1, prediction: 3.3
# test[89] - expected: 3.6, prediction: 2.8
# test[90] - expected: 4.1, prediction: 4.5
# test[91] - expected: 4.7, prediction: 5.0
# test[92] - expected: 5.4, prediction: 5.0
# test[93] - expected: 3.5, prediction: 3.1
# test[94] - expected: 3.3, prediction: 3.9
# test[95] - expected: 5.4, prediction: 6.7
# test[96] - expected: 5.5, prediction: 6.4
# test[97] - expected: 5.5, prediction: 4.4
# test[98] - expected: 4.7, prediction: 4.0
# test[99] - expected: 3.5, prediction: 4.0
# test[100] - expected: 3.6, prediction: 3.6
# test[101] - expected: 5.1, prediction: 3.8
# test[102] - expected: 4.0, prediction: 2.9
# test[103] - expected: 4.9, prediction: 3.2
# test[104] - expected: 4.1, prediction: 2.9
# test[105] - expected: 4.7, prediction: 5.7
# test[106] - expected: 4.1, prediction: 4.0
# test[107] - expected: 5.1, prediction: 5.6
# test[108] - expected: 5.1, prediction: 5.4
# test[109] - expected: 4.3, prediction: 4.8
# test[110] - expected: 4.7, prediction: 3.5
# test[111] - expected: 3.6, prediction: 3.3
# test[112] - expected: 4.0, prediction: 6.0
# test[113] - expected: 3.7, prediction: 2.9
# test[114] - expected: 3.6, prediction: 3.1
# test[115] - expected: 4.2, prediction: 3.4
# test[116] - expected: 3.9, prediction: 3.3
# test[117] - expected: 3.9, prediction: 4.4
# test[118] - expected: 4.3, prediction: 3.2
# test[119] - expected: 4.9, prediction: 4.7
# test[120] - expected: 4.4, prediction: 4.7
# test[121] - expected: 5.0, prediction: 5.4
# test[122] - expected: 4.5, prediction: 3.9
# test[123] - expected: 4.2, prediction: 3.6
# test[124] - expected: 4.1, prediction: 3.0
# test[125] - expected: 3.4, prediction: 3.3
# test[126] - expected: 4.2, prediction: 5.2
# test[127] - expected: 4.2, prediction: 3.0
# test[128] - expected: 4.2, prediction: 3.1
# test[129] - expected: 4.1, prediction: 3.6
# test[130] - expected: 4.2, prediction: 4.8
# test[131] - expected: 3.7, prediction: 2.8
# test[132] - expected: 4.8, prediction: 4.3
# test[133] - expected: 4.2, prediction: 3.5
# test[134] - expected: 5.7, prediction: 5.1
# test[135] - expected: 4.7, prediction: 6.5
# test[136] - expected: 4.9, prediction: 4.3
# test[137] - expected: 5.2, prediction: 5.9
# test[138] - expected: 5.0, prediction: 4.8
# test[139] - expected: 3.7, prediction: 2.9
# test[140] - expected: 3.9, prediction: 4.1
# test[141] - expected: 5.2, prediction: 4.6
# test[142] - expected: 4.8, prediction: 5.3
# test[143] - expected: 4.4, prediction: 4.3
# test[144] - expected: 5.6, prediction: 6.1
# test[145] - expected: 4.1, prediction: 3.4
# test[146] - expected: 4.0, prediction: 2.4
# test[147] - expected: 4.5, prediction: 5.7
# test[148] - expected: 3.5, prediction: 3.9
# test[149] - expected: 3.3, prediction: 3.1
# test[150] - expected: 4.4, prediction: 3.0
# test[151] - expected: 4.4, prediction: 4.7
# test[152] - expected: 5.5, prediction: 4.1
# test[153] - expected: 5.7, prediction: 7.1
# test[154] - expected: 4.1, prediction: 5.4
# test[155] - expected: 3.9, prediction: 3.5
# test[156] - expected: 4.3, prediction: 4.0
# test[157] - expected: 4.7, prediction: 4.6
# test[158] - expected: 3.6, prediction: 3.0
# test[159] - expected: 2.8, prediction: 2.4
# test[160] - expected: 3.6, prediction: 3.1
# test[161] - expected: 3.9, prediction: 5.3
# test[162] - expected: 3.8, prediction: 2.9
# test[163] - expected: 5.1, prediction: 5.3
# test[164] - expected: 3.7, prediction: 4.3
# test[165] - expected: 3.9, prediction: 4.1
# test[166] - expected: 4.3, prediction: 4.8
# test[167] - expected: 3.8, prediction: 3.0
# test[168] - expected: 3.8, prediction: 3.8
# test[169] - expected: 4.2, prediction: 4.4
# test[170] - expected: 3.5, prediction: 3.2
# test[171] - expected: 3.5, prediction: 2.9
# test[172] - expected: 3.9, prediction: 3.5
# test[173] - expected: 3.1, prediction: 2.7
# test[174] - expected: 4.8, prediction: 5.2
# test[175] - expected: 4.9, prediction: 3.3
# test[176] - expected: 4.0, prediction: 5.1
# test[177] - expected: 4.6, prediction: 5.2
# test[178] - expected: 3.2, prediction: 3.1
# test[179] - expected: 5.0, prediction: 3.4
# test[180] - expected: 5.3, prediction: 6.0
# test[181] - expected: 4.2, prediction: 5.1
# test[182] - expected: 3.5, prediction: 3.3
# test[183] - expected: 4.3, prediction: 3.3
# test[184] - expected: 5.5, prediction: 5.1
# test[185] - expected: 5.0, prediction: 4.2
# test[186] - expected: 4.1, prediction: 3.7
# test[187] - expected: 4.7, prediction: 3.0
# test[188] - expected: 5.6, prediction: 6.0
# test[189] - expected: 4.3, prediction: 4.1
# test[190] - expected: 4.3, prediction: 4.0
# test[191] - expected: 4.6, prediction: 4.5
# test[192] - expected: 3.5, prediction: 2.6
# test[193] - expected: 4.4, prediction: 2.8
# test[194] - expected: 5.8, prediction: 6.6
# test[195] - expected: 4.4, prediction: 3.6
# test[196] - expected: 5.3, prediction: 5.9
# test[197] - expected: 5.5, prediction: 4.9
# test[198] - expected: 5.7, prediction: 6.2
# test[199] - expected: 5.7, prediction: 5.3
# test[200] - expected: 6.1, prediction: 5.3
# test[201] - expected: 5.7, prediction: 4.1
# test[202] - expected: 4.4, prediction: 4.0
# test[203] - expected: 5.3, prediction: 4.7
# test[204] - expected: 5.5, prediction: 5.0
# test[205] - expected: 5.9, prediction: 5.7
# test[206] - expected: 5.6, prediction: 5.8
# test[207] - expected: 4.9, prediction: 5.8
# test[208] - expected: 4.6, prediction: 4.5
# test[209] - expected: 5.5, prediction: 6.0
# test[210] - expected: 5.3, prediction: 3.2
# test[211] - expected: 5.2, prediction: 4.1
# test[212] - expected: 5.5, prediction: 4.4
# test[213] - expected: 5.4, prediction: 6.6
# test[214] - expected: 4.6, prediction: 3.5
# test[215] - expected: 3.9, prediction: 5.6
# test[216] - expected: 4.4, prediction: 5.7
# test[217] - expected: 5.4, prediction: 4.5
# test[218] - expected: 4.5, prediction: 3.7
# test[219] - expected: 6.3, prediction: 6.7
# test[220] - expected: 6.7, prediction: 6.6
# test[221] - expected: 4.2, prediction: 3.6
# test[222] - expected: 4.7, prediction: 5.3
# test[223] - expected: 6.7, prediction: 5.6
# test[224] - expected: 4.5, prediction: 5.2
# test[225] - expected: 4.1, prediction: 3.2
# test[226] - expected: 5.2, prediction: 5.7
# test[227] - expected: 4.3, prediction: 3.2
# test[228] - expected: 4.6, prediction: 4.6
# test[229] - expected: 4.3, prediction: 2.9
# test[230] - expected: 5.5, prediction: 5.0
# test[231] - expected: 5.2, prediction: 5.7
# test[232] - expected: 6.2, prediction: 5.4
# test[233] - expected: 5.7, prediction: 3.1
# test[234] - expected: 5.4, prediction: 6.3
# test[235] - expected: 4.4, prediction: 4.7
# test[236] - expected: 4.6, prediction: 5.5
# test[237] - expected: 5.7, prediction: 5.9
# test[238] - expected: 5.2, prediction: 5.8
# test[239] - expected: 3.9, prediction: 2.6
# test[240] - expected: 5.9, prediction: 5.0
# test[241] - expected: 4.7, prediction: 5.8
# test[242] - expected: 4.0, prediction: 2.7
# test[243] - expected: 3.6, prediction: 3.3
# test[244] - expected: 5.2, prediction: 4.7
# test[245] - expected: 4.2, prediction: 5.7
# test[246] - expected: 5.1, prediction: 4.5
# test[247] - expected: 5.2, prediction: 6.0
# test[248] - expected: 6.0, prediction: 6.7
# test[249] - expected: 5.4, prediction: 5.0
# test[250] - expected: 5.6, prediction: 5.6
# test[251] - expected: 5.1, prediction: 5.0
# test[252] - expected: 4.3, prediction: 3.5
# test[253] - expected: 4.2, prediction: 5.0
# test[254] - expected: 4.7, prediction: 4.9
# test[255] - expected: 5.1, prediction: 5.7
# test[256] - expected: 5.6, prediction: 7.4
# test[257] - expected: 5.1, prediction: 5.9
# test[258] - expected: 3.8, prediction: 4.5
# test[259] - expected: 3.8, prediction: 4.0
# test[260] - expected: 5.2, prediction: 5.0
# test[261] - expected: 3.5, prediction: 3.7
# test[262] - expected: 4.9, prediction: 5.6
# test[263] - expected: 5.6, prediction: 6.6
# test[264] - expected: 4.9, prediction: 4.2
# test[265] - expected: 3.9, prediction: 3.4
# test[266] - expected: 5.5, prediction: 6.3
# test[267] - expected: 4.4, prediction: 6.2
# test[268] - expected: 4.5, prediction: 5.0
# test[269] - expected: 5.2, prediction: 5.5
# test[270] - expected: 5.0, prediction: 6.3
# test[271] - expected: 5.8, prediction: 6.4
# test[272] - expected: 5.6, prediction: 3.2
# test[273] - expected: 5.1, prediction: 5.2
# test[274] - expected: 5.8, prediction: 6.2
# test[275] - expected: 4.5, prediction: 4.5
# test[276] - expected: 6.2, prediction: 5.6
# test[277] - expected: 4.6, prediction: 3.9
# test[278] - expected: 3.5, prediction: 3.0
# test[279] - expected: 5.2, prediction: 5.8
# test[280] - expected: 3.4, prediction: 3.2
# test[281] - expected: 5.6, prediction: 5.5
# test[282] - expected: 5.6, prediction: 5.8
# test[283] - expected: 3.9, prediction: 3.5
# test[284] - expected: 5.2, prediction: 6.1
# test[285] - expected: 4.6, prediction: 6.2
# test[286] - expected: 4.8, prediction: 4.8
# test[287] - expected: 4.7, prediction: 5.9
# test[288] - expected: 4.5, prediction: 2.1
# test[289] - expected: 4.3, prediction: 3.8
# test[290] - expected: 5.0, prediction: 4.2
# test[291] - expected: 3.4, prediction: 4.1
# test[292] - expected: 5.8, prediction: 6.7
# test[293] - expected: 5.0, prediction: 6.4
# test[294] - expected: 6.0, prediction: 7.3
# test[295] - expected: 6.0, prediction: 6.9
# test[296] - expected: 4.8, prediction: 3.4
# test[297] - expected: 6.1, prediction: 6.5
# test[298] - expected: 5.3, prediction: 6.2
# test[299] - expected: 5.7, prediction: 6.5
# test[300] - expected: 4.6, prediction: 5.1
# test[301] - expected: 5.9, prediction: 5.0
# test[302] - expected: 4.4, prediction: 3.3
# test[303] - expected: 6.0, prediction: 5.4
# test[304] - expected: 5.1, prediction: 5.5
# test[305] - expected: 5.4, prediction: 6.5
# test[306] - expected: 7.0, prediction: 6.3
# test[307] - expected: 5.3, prediction: 6.5
# test[308] - expected: 5.3, prediction: 6.3
# test[309] - expected: 4.6, prediction: 4.6
# test[310] - expected: 4.6, prediction: 4.6
# test[311] - expected: 6.1, prediction: 5.4
# test[312] - expected: 5.6, prediction: 6.4
# test[313] - expected: 5.5, prediction: 6.5
# test[314] - expected: 5.9, prediction: 5.8
# test[315] - expected: 5.6, prediction: 6.2
# test[316] - expected: 6.8, prediction: 5.7
# test[317] - expected: 5.3, prediction: 4.5
# test[318] - expected: 5.8, prediction: 6.1
# test[319] - expected: 4.3, prediction: 4.6
# test[320] - expected: 4.8, prediction: 5.6
# test[321] - expected: 5.4, prediction: 6.7
# test[322] - expected: 4.9, prediction: 4.0
# test[323] - expected: 5.4, prediction: 5.5
# test[324] - expected: 5.5, prediction: 6.0
# test[325] - expected: 5.6, prediction: 7.0
# test[326] - expected: 4.1, prediction: 3.8
# test[327] - expected: 5.5, prediction: 4.4
# test[328] - expected: 4.3, prediction: 3.0
# test[329] - expected: 4.4, prediction: 3.9
# test[330] - expected: 5.8, prediction: 7.0
# test[331] - expected: 4.0, prediction: 3.2
# test[332] - expected: 5.7, prediction: 5.6
# test[333] - expected: 5.6, prediction: 4.4
# test[334] - expected: 5.6, prediction: 6.8
# test[335] - expected: 4.6, prediction: 4.4
# test[336] - expected: 4.1, prediction: 5.1
# test[337] - expected: 5.3, prediction: 6.1
# test[338] - expected: 5.7, prediction: 6.0
# test[339] - expected: 5.6, prediction: 7.4
# test[340] - expected: 5.6, prediction: 6.7
# test[341] - expected: 4.1, prediction: 5.1
# test[342] - expected: 4.0, prediction: 3.4
# test[343] - expected: 5.8, prediction: 4.0
# test[344] - expected: 5.4, prediction: 4.4
# test[345] - expected: 5.0, prediction: 4.4
# test[346] - expected: 5.9, prediction: 5.7
# test[347] - expected: 5.5, prediction: 6.5
# test[348] - expected: 5.7, prediction: 5.9
# test[349] - expected: 5.7, prediction: 4.8
# test[350] - expected: 4.3, prediction: 5.1
# test[351] - expected: 5.1, prediction: 5.8
# test[352] - expected: 5.9, prediction: 6.7
# test[353] - expected: 5.9, prediction: 5.3
# test[354] - expected: 4.5, prediction: 5.0
# test[355] - expected: 5.7, prediction: 5.5
# test[356] - expected: 6.4, prediction: 6.7
# test[357] - expected: 3.7, prediction: 3.5
# test[358] - expected: 4.7, prediction: 5.0
# test[359] - expected: 6.1, prediction: 6.9
# test[360] - expected: 5.9, prediction: 6.2
# test[361] - expected: 4.7, prediction: 5.7
# test[362] - expected: 6.7, prediction: 7.1
# test[363] - expected: 5.1, prediction: 5.5
# test[364] - expected: 4.7, prediction: 5.9
# test[365] - expected: 4.7, prediction: 4.3
# test[366] - expected: 4.1, prediction: 4.7
# test[367] - expected: 4.7, prediction: 5.6
# test[368] - expected: 4.6, prediction: 5.4
# test[369] - expected: 5.2, prediction: 5.2
# test[370] - expected: 6.0, prediction: 6.5
# test[371] - expected: 5.3, prediction: 7.2
# test[372] - expected: 5.6, prediction: 5.4
# test[373] - expected: 7.7, prediction: 5.8
# test[374] - expected: 3.8, prediction: 4.5
# test[375] - expected: 4.1, prediction: 3.4
# test[376] - expected: 3.5, prediction: 2.9
# test[377] - expected: 4.7, prediction: 5.6
# test[378] - expected: 5.2, prediction: 5.1
# test[379] - expected: 5.7, prediction: 6.3
# test[380] - expected: 5.4, prediction: 5.8
# test[381] - expected: 5.2, prediction: 5.7
# test[382] - expected: 4.5, prediction: 4.1
# test[383] - expected: 5.0, prediction: 6.0
# test[384] - expected: 6.7, prediction: 6.8
# test[385] - expected: 6.5, prediction: 7.0
# test[386] - expected: 5.0, prediction: 3.5
# test[387] - expected: 4.3, prediction: 4.7
# test[388] - expected: 4.5, prediction: 5.9
# test[389] - expected: 4.4, prediction: 3.9
# test[390] - expected: 5.2, prediction: 6.2
# test[391] - expected: 4.8, prediction: 5.4
# test[392] - expected: 5.4, prediction: 6.0
# test[393] - expected: 5.2, prediction: 6.6
# test[394] - expected: 5.8, prediction: 5.2
# test[395] - expected: 4.5, prediction: 4.6
# test[396] - expected: 4.3, prediction: 4.8
# test[397] - expected: 4.7, prediction: 5.2
# test[398] - expected: 4.3, prediction: 3.2
# test[399] - expected: 5.6, prediction: 4.4
# test[400] - expected: 5.2, prediction: 3.6
# test[401] - expected: 4.6, prediction: 4.2
# test[402] - expected: 3.6, prediction: 4.8
# test[403] - expected: 5.7, prediction: 5.0
# test[404] - expected: 4.4, prediction: 5.2
# test[405] - expected: 5.7, prediction: 5.6
# test[406] - expected: 5.1, prediction: 6.6
# test[407] - expected: 5.4, prediction: 5.4
# test[408] - expected: 6.1, prediction: 5.6
# test[409] - expected: 4.2, prediction: 6.5
# test[410] - expected: 5.6, prediction: 6.3
# test[411] - expected: 4.9, prediction: 6.8
# test[412] - expected: 4.4, prediction: 5.8
# test[413] - expected: 5.3, prediction: 4.4
# test[414] - expected: 5.1, prediction: 4.4
# test[415] - expected: 5.0, prediction: 3.0
# test[416] - expected: 5.0, prediction: 4.4
# test[417] - expected: 5.0, prediction: 4.8
# test[418] - expected: 5.4, prediction: 4.0
# test[419] - expected: 5.5, prediction: 5.4
# test[420] - expected: 4.6, prediction: 6.2
# test[421] - expected: 5.5, prediction: 4.0
# test[422] - expected: 5.8, prediction: 6.2
# test[423] - expected: 4.4, prediction: 3.4
# test[424] - expected: 5.0, prediction: 4.4
# test[425] - expected: 4.8, prediction: 6.8
# test[426] - expected: 4.1, prediction: 4.6
# test[427] - expected: 5.3, prediction: 4.6
# test[428] - expected: 5.6, prediction: 4.7
# test[429] - expected: 5.0, prediction: 4.4
# test[430] - expected: 4.9, prediction: 3.8
# test[431] - expected: 4.0, prediction: 4.6
# test[432] - expected: 6.0, prediction: 7.0
# test[433] - expected: 4.0, prediction: 3.0
# test[434] - expected: 5.1, prediction: 4.6
# test[435] - expected: 4.0, prediction: 4.4
# test[436] - expected: 4.5, prediction: 5.2
# test[437] - expected: 3.6, prediction: 3.2
# test[438] - expected: 5.5, prediction: 5.2
# test[439] - expected: 5.1, prediction: 5.0
# test[440] - expected: 3.4, prediction: 3.6
# test[441] - expected: 4.6, prediction: 3.8
# test[442] - expected: 4.6, prediction: 3.6
# test[443] - expected: 4.7, prediction: 4.6
# test[444] - expected: 5.2, prediction: 5.2
# test[445] - expected: 3.9, prediction: 3.8
# test[446] - expected: 3.1, prediction: 3.6
# test[447] - expected: 6.2, prediction: 5.2
# test[448] - expected: 4.6, prediction: 4.6
# test[449] - expected: 6.0, prediction: 6.8
# test[450] - expected: 5.3, prediction: 5.8
# Differences
# Less than one: 342
# Less than two: 102
# Less than three: 7

# %%
less_than_one+less_than_two+less_than_three
# Out:
# 451
