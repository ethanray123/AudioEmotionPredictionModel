# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
import math
print(tf.__version__)
# Out:
# 1.10.0
# Using TensorFlow backend.

# %%
# LOAD DATA
# manual method of separating data (not necessary)
# x_train = np.load("train_x.npy")
# valence_y_train = np.load("valence_train_y.npy")
# x_test = np.load("test_x.npy")
# valence_y_test = np.load("valence_test_y.npy")

# valence_y_train = valence_y_train.flatten()
# valence_y_test = valence_y_test.flatten()

audio_data = np.load("audio_data.npy")
valence_labels = np.load("valence_labels.npy")

x_train, x_test, valence_y_train, valence_y_test = train_test_split(
    audio_data, valence_labels, test_size=0.5, random_state=0)

print("training set: {}".format(x_train.shape))
print("valence_y_train: {}".format(valence_y_train.shape))
print("testing set: {}".format(x_test.shape))
print("valence_y_test: {}".format(valence_y_test.shape))
# Out:
# training set: (901, 193)
# valence_y_train: (901,)
# testing set: (901, 193)
# valence_y_test: (901,)

# %%
# Normalize the data

# Display sample features
print(x_train[0][1], type(x_train[0][1]))  

# another method of normalizing data
# Using mean and standard deviation
# mean = x_train.mean(axis=0)
# std = x_train.std(axis=0)
# x_train = (x_train - mean) / std
# x_test = (x_test - mean) / std

# Using keras utilities normalize
# scales data between 0 and 1
x_train = keras.utils.normalize(x_train, axis=1)  
x_test = keras.utils.normalize(x_test, axis=1)  

# notice the different scales
print(x_train[0][1], type(x_train[0][1]))
# Out:
# 118.10459904226647 <class 'numpy.float64'>
# 0.6266310774136582 <class 'numpy.float64'>

# %%
def build_model():
    model = keras.Sequential([
        keras.layers.Dense(193, activation=tf.nn.relu, 
                           input_shape=(x_train.shape[1],)),
        keras.layers.Dense(97, activation=tf.nn.relu),
        keras.layers.Dense(1, activation='linear')
    ])

#     optimizer = tf.train.RMSPropOptimizer(0.001)

    model.compile(loss='mse',
                optimizer='adam', # 'rmsprop'
                metrics=['mae'])
    return model

val_model = KerasRegressor(build_fn=build_model, 
                                 epochs=10, 
                                 batch_size=100, 
                                 verbose=0)
# this is to see the summary of what the build model() 
# function creates. aro_model is the model we're developing
model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 193)               37442
# _________________________________________________________________
# dense_1 (Dense)              (None, 97)                18818
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 98
# =================================================================
# Total params: 56,358
# Trainable params: 56,358
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Display training progress by printing a single dot for each 
# completed epoch. This is an example model training process
# using 500 iterations (EPOCHS)
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 500

# Store training stats
history = model.fit(x_train, valence_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
# This will plot a diagram that shows the mean absolute error

def plot_history(history):
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [Valence]')
  plt.plot(history.epoch, 
           np.array(history.history['mean_absolute_error']), 
           label='Train Loss')
  plt.plot(history.epoch, 
           np.array(history.history['val_mean_absolute_error']),
           label = 'Val loss')
  plt.legend()
  plt.ylim([0,5])

# %%
plot_history(history)

# %%
# This will re-initialize the building of the model. 
# Fresh start not trained
model = build_model()

# The patience parameter is the amount of epochs to check for 
# improvement. Once the model isn't improving after 20 epochs,
# the training will stop
early_stop = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20)

# this is just for showing the diagram again using the dummy model
history = model.fit(x_train, valence_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])
# plotting
plot_history(history)

# we will now train the actual model like this. 
# Seems to be a good idea
val_model.fit(x_train, valence_y_train, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])
# Out:
# ...........................................................
# .................................................

# %%
# The actual model will be subjected to cross validation now
scores = cross_val_score(
    val_model, 
    audio_data, #x_test, 
    valence_labels, #valence_y_test,
    scoring='neg_mean_squared_error', 
    cv=10)

# Results
# Sir Ken and Sir Capao say that the rmse value is acceptable 
# close to 0 is good from what I remember
print("\nTesting Set mean squared error:",abs(scores.mean()))
rmse = math.sqrt(abs(scores.mean()))
print("Testing Set root mean squared error:", rmse)
[loss, mae] = model.evaluate(x_test, valence_y_test, verbose=0)
print("Testing set Loss:{:7.2f}".format(loss))
print("Testing set Mean Abs Error:{:7.2f}".format(mae))
# Out:
# Testing Set mean squared error: 5.746174829238467
# Testing Set root mean squared error: 2.397118025721401
# Testing set Loss:   1.03
# Testing set Mean Abs Error:   0.81

# %%
# we will now let the model predict
test_predictions = val_model.predict(x_test).flatten()
# test_predictions are the predictions given by the model
print(len(test_predictions))
print(len(valence_y_test))
# Out:
# 901
# 901

# %%
# this is the summary of comparison between the expected values
# and the predicted values. 
less_than_one=0 # 0.1-0.9 difference
less_than_two=0 # 1.0-1.9 difference
less_than_three=0 # 2.0-2.9 difference
not_manageable=0 # 3.0 and beyond

for i in range(len(valence_y_test)):
    diff = abs(test_predictions[i] - valence_y_test[i])
    if(diff < 1):
        less_than_one = less_than_one + 1
    elif(diff < 2):
        less_than_two = less_than_two + 1
    elif(diff < 3):
        less_than_three = less_than_three + 1
    else:
        not_manageable = not_manageable + 1
        print("test[{}] - values different by {:.1f}".format(i,diff))
    print("test[{0:}] - expected: {1:.1f}, prediction: {2:.1f}".format(i,test_predictions[i],valence_y_test[i]))
print("Summary of Differences:\nLess than one: {}\nLess than two: {}\nLess than three: {}\nUnmanageable: {}".format(less_than_one,less_than_two,less_than_three,not_manageable))


# print("test[436] - expected: {0:.1f}, prediction: {1:.1f}".format(test_predictions[436],valence_y_test[436]))
# Out:
# test[0] - expected: 5.4, prediction: 4.5
# test[1] - expected: 4.7, prediction: 4.4
# test[2] - expected: 5.1, prediction: 5.0
# test[3] - expected: 5.0, prediction: 6.1
# test[4] - expected: 6.3, prediction: 5.1
# test[5] - expected: 4.7, prediction: 4.4
# test[6] - expected: 5.3, prediction: 3.7
# test[7] - expected: 3.8, prediction: 3.2
# test[8] - expected: 5.5, prediction: 5.8
# test[9] - expected: 4.7, prediction: 6.3
# test[10] - expected: 4.4, prediction: 3.9
# test[11] - expected: 3.7, prediction: 3.7
# test[12] - expected: 4.2, prediction: 4.2
# test[13] - expected: 5.3, prediction: 4.1
# test[14] - expected: 4.7, prediction: 5.2
# test[15] - expected: 4.1, prediction: 4.0
# test[16] - expected: 5.7, prediction: 7.0
# test[17] - expected: 5.4, prediction: 6.1
# test[18] - expected: 6.5, prediction: 7.4
# test[19] - expected: 5.2, prediction: 6.0
# test[20] - expected: 4.6, prediction: 4.2
# test[21] - expected: 4.6, prediction: 4.3
# test[22] - expected: 5.9, prediction: 5.0
# test[23] - expected: 4.9, prediction: 5.8
# test[24] - expected: 4.6, prediction: 4.2
# test[25] - expected: 4.5, prediction: 3.7
# test[26] - expected: 4.3, prediction: 4.4
# test[27] - expected: 5.6, prediction: 4.2
# test[28] - expected: 5.2, prediction: 6.2
# test[29] - expected: 5.1, prediction: 5.7
# test[30] - expected: 4.8, prediction: 4.6
# test[31] - expected: 4.3, prediction: 5.8
# test[32] - expected: 3.7, prediction: 4.2
# test[33] - expected: 5.2, prediction: 4.1
# test[34] - expected: 5.8, prediction: 4.2
# test[35] - expected: 5.0, prediction: 5.5
# test[36] - expected: 5.3, prediction: 6.1
# test[37] - expected: 4.3, prediction: 3.8
# test[38] - expected: 5.4, prediction: 5.1
# test[39] - expected: 4.5, prediction: 4.2
# test[40] - expected: 5.3, prediction: 6.4
# test[41] - expected: 5.0, prediction: 5.7
# test[42] - expected: 5.1, prediction: 7.3
# test[43] - expected: 5.2, prediction: 4.4
# test[44] - expected: 5.1, prediction: 4.8
# test[45] - expected: 5.5, prediction: 5.6
# test[46] - expected: 4.1, prediction: 3.3
# test[47] - expected: 6.2, prediction: 4.7
# test[48] - expected: 4.8, prediction: 5.4
# test[49] - expected: 5.1, prediction: 6.4
# test[50] - expected: 5.0, prediction: 3.5
# test[51] - expected: 4.1, prediction: 5.3
# test[52] - expected: 4.9, prediction: 4.0
# test[53] - values different by 3.3
# test[53] - expected: 7.4, prediction: 4.1
# test[54] - expected: 5.4, prediction: 6.3
# test[55] - expected: 5.7, prediction: 5.3
# test[56] - expected: 4.6, prediction: 6.4
# test[57] - expected: 5.5, prediction: 4.7
# test[58] - expected: 4.6, prediction: 5.4
# test[59] - expected: 4.3, prediction: 4.8
# test[60] - expected: 4.7, prediction: 2.8
# test[61] - expected: 5.0, prediction: 4.9
# test[62] - expected: 5.3, prediction: 6.2
# test[63] - expected: 5.4, prediction: 4.2
# test[64] - expected: 4.8, prediction: 4.5
# test[65] - expected: 4.6, prediction: 6.8
# test[66] - expected: 5.2, prediction: 6.0
# test[67] - expected: 4.1, prediction: 4.1
# test[68] - expected: 4.9, prediction: 3.7
# test[69] - expected: 5.5, prediction: 3.7
# test[70] - expected: 4.5, prediction: 4.6
# test[71] - expected: 5.2, prediction: 4.9
# test[72] - expected: 5.4, prediction: 6.0
# test[73] - expected: 6.1, prediction: 3.2
# test[74] - expected: 3.8, prediction: 4.2
# test[75] - expected: 6.4, prediction: 7.2
# test[76] - expected: 4.9, prediction: 5.4
# test[77] - expected: 4.9, prediction: 4.2
# test[78] - expected: 5.2, prediction: 4.1
# test[79] - expected: 5.4, prediction: 3.4
# test[80] - expected: 7.0, prediction: 6.4
# test[81] - expected: 5.4, prediction: 5.9
# test[82] - expected: 5.4, prediction: 7.7
# test[83] - expected: 6.0, prediction: 4.6
# test[84] - expected: 4.9, prediction: 5.2
# test[85] - expected: 4.9, prediction: 4.5
# test[86] - expected: 4.3, prediction: 4.1
# test[87] - expected: 4.5, prediction: 3.6
# test[88] - expected: 4.7, prediction: 5.1
# test[89] - expected: 4.6, prediction: 5.2
# test[90] - expected: 5.4, prediction: 5.4
# test[91] - expected: 4.2, prediction: 3.6
# test[92] - expected: 4.7, prediction: 3.5
# test[93] - expected: 4.9, prediction: 6.1
# test[94] - expected: 3.9, prediction: 3.2
# test[95] - expected: 5.0, prediction: 4.5
# test[96] - expected: 5.4, prediction: 6.0
# test[97] - expected: 5.6, prediction: 5.2
# test[98] - expected: 5.5, prediction: 4.3
# test[99] - expected: 5.6, prediction: 4.8
# test[100] - expected: 5.3, prediction: 5.2
# test[101] - expected: 5.5, prediction: 5.2
# test[102] - expected: 4.0, prediction: 3.7
# test[103] - expected: 6.1, prediction: 5.6
# test[104] - expected: 3.8, prediction: 3.2
# test[105] - expected: 4.5, prediction: 5.1
# test[106] - expected: 5.4, prediction: 4.5
# test[107] - expected: 4.1, prediction: 3.3
# test[108] - expected: 5.4, prediction: 4.8
# test[109] - expected: 4.8, prediction: 3.5
# test[110] - expected: 5.3, prediction: 5.8
# test[111] - expected: 4.8, prediction: 6.1
# test[112] - expected: 4.7, prediction: 5.9
# test[113] - expected: 5.1, prediction: 5.6
# test[114] - expected: 4.8, prediction: 5.9
# test[115] - expected: 4.4, prediction: 4.4
# test[116] - expected: 5.4, prediction: 4.0
# test[117] - expected: 5.3, prediction: 6.5
# test[118] - expected: 5.6, prediction: 5.6
# test[119] - expected: 6.7, prediction: 6.6
# test[120] - expected: 4.5, prediction: 5.4
# test[121] - expected: 4.8, prediction: 4.4
# test[122] - expected: 5.3, prediction: 5.8
# test[123] - expected: 3.7, prediction: 3.7
# test[124] - expected: 4.7, prediction: 5.0
# test[125] - expected: 4.7, prediction: 4.0
# test[126] - expected: 5.7, prediction: 3.1
# test[127] - expected: 6.0, prediction: 5.0
# test[128] - expected: 6.1, prediction: 5.4
# test[129] - expected: 4.8, prediction: 6.6
# test[130] - expected: 4.8, prediction: 6.2
# test[131] - expected: 5.1, prediction: 4.8
# test[132] - expected: 4.1, prediction: 5.8
# test[133] - expected: 4.3, prediction: 3.7
# test[134] - expected: 5.7, prediction: 4.0
# test[135] - expected: 5.2, prediction: 5.6
# test[136] - expected: 5.2, prediction: 4.8
# test[137] - expected: 3.9, prediction: 3.1
# test[138] - expected: 5.1, prediction: 6.8
# test[139] - expected: 4.7, prediction: 4.0
# test[140] - expected: 5.6, prediction: 5.9
# test[141] - expected: 5.6, prediction: 6.6
# test[142] - expected: 4.9, prediction: 5.3
# test[143] - expected: 4.0, prediction: 4.4
# test[144] - expected: 4.6, prediction: 5.3
# test[145] - expected: 5.3, prediction: 6.0
# test[146] - expected: 4.4, prediction: 3.6
# test[147] - expected: 4.4, prediction: 3.8
# test[148] - expected: 4.1, prediction: 4.5
# test[149] - expected: 5.8, prediction: 7.1
# test[150] - expected: 4.2, prediction: 3.4
# test[151] - expected: 5.3, prediction: 5.4
# test[152] - expected: 4.0, prediction: 3.4
# test[153] - expected: 3.8, prediction: 2.7
# test[154] - expected: 6.4, prediction: 7.3
# test[155] - expected: 4.7, prediction: 7.5
# test[156] - expected: 5.4, prediction: 5.0
# test[157] - expected: 4.9, prediction: 4.1
# test[158] - expected: 5.4, prediction: 6.9
# test[159] - expected: 5.7, prediction: 6.6
# test[160] - expected: 5.0, prediction: 5.5
# test[161] - expected: 5.0, prediction: 3.3
# test[162] - expected: 5.0, prediction: 6.4
# test[163] - expected: 6.0, prediction: 5.1
# test[164] - expected: 6.0, prediction: 5.2
# test[165] - expected: 5.6, prediction: 5.7
# test[166] - expected: 6.3, prediction: 7.1
# test[167] - expected: 5.4, prediction: 5.7
# test[168] - expected: 6.8, prediction: 5.5
# test[169] - expected: 3.8, prediction: 1.6
# test[170] - expected: 5.6, prediction: 3.3
# test[171] - expected: 5.0, prediction: 5.3
# test[172] - expected: 5.5, prediction: 6.2
# test[173] - expected: 5.2, prediction: 5.1
# test[174] - expected: 5.3, prediction: 5.5
# test[175] - expected: 5.5, prediction: 6.6
# test[176] - expected: 5.3, prediction: 6.0
# test[177] - expected: 4.1, prediction: 4.1
# test[178] - expected: 4.9, prediction: 5.0
# test[179] - expected: 4.8, prediction: 6.2
# test[180] - expected: 5.4, prediction: 6.9
# test[181] - expected: 5.5, prediction: 6.0
# test[182] - expected: 5.1, prediction: 6.1
# test[183] - expected: 4.8, prediction: 3.2
# test[184] - expected: 6.3, prediction: 6.1
# test[185] - expected: 5.1, prediction: 5.2
# test[186] - expected: 3.6, prediction: 3.6
# test[187] - expected: 4.0, prediction: 4.4
# test[188] - expected: 5.6, prediction: 3.7
# test[189] - expected: 5.8, prediction: 5.5
# test[190] - expected: 5.6, prediction: 6.6
# test[191] - expected: 4.6, prediction: 5.0
# test[192] - expected: 4.7, prediction: 4.5
# test[193] - expected: 4.5, prediction: 5.2
# test[194] - expected: 4.9, prediction: 4.3
# test[195] - expected: 5.9, prediction: 5.8
# test[196] - expected: 4.9, prediction: 3.6
# test[197] - expected: 6.4, prediction: 7.3
# test[198] - expected: 4.1, prediction: 3.9
# test[199] - expected: 4.4, prediction: 5.4
# test[200] - expected: 4.0, prediction: 3.1
# test[201] - expected: 3.9, prediction: 4.2
# test[202] - expected: 5.2, prediction: 5.0
# test[203] - expected: 5.1, prediction: 7.1
# test[204] - expected: 4.7, prediction: 6.3
# test[205] - expected: 5.3, prediction: 5.2
# test[206] - expected: 5.4, prediction: 5.9
# test[207] - expected: 4.6, prediction: 3.7
# test[208] - expected: 5.9, prediction: 5.8
# test[209] - expected: 5.5, prediction: 5.0
# test[210] - expected: 4.4, prediction: 4.7
# test[211] - expected: 6.3, prediction: 5.2
# test[212] - expected: 4.5, prediction: 4.6
# test[213] - expected: 4.0, prediction: 5.3
# test[214] - expected: 6.1, prediction: 6.2
# test[215] - expected: 5.6, prediction: 4.8
# test[216] - expected: 4.2, prediction: 4.5
# test[217] - expected: 5.5, prediction: 5.3
# test[218] - expected: 3.9, prediction: 4.3
# test[219] - expected: 6.4, prediction: 4.2
# test[220] - expected: 3.8, prediction: 3.7
# test[221] - expected: 4.4, prediction: 4.7
# test[222] - expected: 3.9, prediction: 2.5
# test[223] - expected: 4.2, prediction: 4.2
# test[224] - expected: 4.2, prediction: 4.9
# test[225] - expected: 5.5, prediction: 5.9
# test[226] - expected: 5.7, prediction: 4.4
# test[227] - expected: 4.8, prediction: 4.5
# test[228] - expected: 4.8, prediction: 3.7
# test[229] - expected: 5.5, prediction: 5.9
# test[230] - expected: 4.2, prediction: 4.6
# test[231] - expected: 4.4, prediction: 3.6
# test[232] - expected: 5.0, prediction: 4.6
# test[233] - expected: 5.4, prediction: 4.6
# test[234] - expected: 5.1, prediction: 4.5
# test[235] - expected: 3.9, prediction: 4.1
# test[236] - expected: 4.5, prediction: 6.5
# test[237] - expected: 5.2, prediction: 6.2
# test[238] - expected: 4.2, prediction: 4.5
# test[239] - expected: 4.7, prediction: 4.7
# test[240] - expected: 4.1, prediction: 4.5
# test[241] - expected: 3.7, prediction: 3.5
# test[242] - expected: 5.9, prediction: 5.6
# test[243] - expected: 4.7, prediction: 4.5
# test[244] - expected: 3.9, prediction: 5.3
# test[245] - expected: 5.9, prediction: 4.6
# test[246] - expected: 5.1, prediction: 4.9
# test[247] - expected: 5.6, prediction: 5.7
# test[248] - expected: 3.8, prediction: 5.7
# test[249] - expected: 3.8, prediction: 4.3
# test[250] - expected: 4.4, prediction: 4.4
# test[251] - expected: 6.3, prediction: 6.0
# test[252] - expected: 4.7, prediction: 4.5
# test[253] - expected: 5.5, prediction: 5.6
# test[254] - expected: 5.0, prediction: 5.3
# test[255] - expected: 6.0, prediction: 6.7
# test[256] - expected: 5.6, prediction: 4.8
# test[257] - expected: 4.2, prediction: 4.0
# test[258] - expected: 4.1, prediction: 2.2
# test[259] - expected: 3.9, prediction: 3.7
# test[260] - expected: 5.5, prediction: 5.7
# test[261] - expected: 4.2, prediction: 3.0
# test[262] - expected: 5.6, prediction: 4.8
# test[263] - expected: 3.8, prediction: 5.1
# test[264] - expected: 6.4, prediction: 5.3
# test[265] - expected: 5.3, prediction: 5.9
# test[266] - expected: 3.8, prediction: 3.3
# test[267] - expected: 4.4, prediction: 3.2
# test[268] - expected: 4.3, prediction: 4.3
# test[269] - expected: 4.3, prediction: 4.6
# test[270] - expected: 3.7, prediction: 2.2
# test[271] - expected: 5.5, prediction: 5.3
# test[272] - expected: 5.5, prediction: 5.5
# test[273] - expected: 5.0, prediction: 7.0
# test[274] - expected: 4.1, prediction: 3.6
# test[275] - expected: 3.8, prediction: 4.8
# test[276] - expected: 5.0, prediction: 4.0
# test[277] - expected: 4.4, prediction: 3.9
# test[278] - expected: 4.2, prediction: 4.0
# test[279] - expected: 5.7, prediction: 6.0
# test[280] - expected: 5.7, prediction: 7.0
# test[281] - expected: 3.8, prediction: 3.4
# test[282] - expected: 6.2, prediction: 6.2
# test[283] - expected: 3.9, prediction: 3.7
# test[284] - expected: 5.6, prediction: 6.0
# test[285] - expected: 4.3, prediction: 4.1
# test[286] - expected: 3.9, prediction: 4.2
# test[287] - expected: 5.1, prediction: 5.0
# test[288] - expected: 5.4, prediction: 6.0
# test[289] - expected: 5.5, prediction: 7.3
# test[290] - expected: 4.1, prediction: 3.9
# test[291] - expected: 4.6, prediction: 4.8
# test[292] - expected: 4.9, prediction: 5.7
# test[293] - expected: 5.6, prediction: 5.7
# test[294] - expected: 4.2, prediction: 4.3
# test[295] - expected: 5.6, prediction: 5.8
# test[296] - expected: 3.8, prediction: 3.0
# test[297] - expected: 4.5, prediction: 4.3
# test[298] - expected: 4.4, prediction: 4.3
# test[299] - expected: 4.6, prediction: 4.5
# test[300] - expected: 3.9, prediction: 3.7
# test[301] - expected: 3.8, prediction: 2.8
# test[302] - expected: 4.6, prediction: 4.4
# test[303] - expected: 5.6, prediction: 6.5
# test[304] - expected: 5.5, prediction: 5.5
# test[305] - expected: 4.1, prediction: 4.4
# test[306] - expected: 4.2, prediction: 5.1
# test[307] - expected: 5.8, prediction: 5.9
# test[308] - expected: 3.9, prediction: 4.4
# test[309] - expected: 5.9, prediction: 3.9
# test[310] - expected: 4.8, prediction: 5.1
# test[311] - expected: 5.0, prediction: 4.7
# test[312] - expected: 5.0, prediction: 4.4
# test[313] - expected: 4.1, prediction: 2.8
# test[314] - expected: 5.1, prediction: 5.9
# test[315] - expected: 4.9, prediction: 5.1
# test[316] - expected: 4.8, prediction: 6.1
# test[317] - expected: 4.9, prediction: 5.6
# test[318] - expected: 4.4, prediction: 3.1
# test[319] - expected: 3.7, prediction: 3.5
# test[320] - expected: 5.5, prediction: 4.8
# test[321] - expected: 4.1, prediction: 2.9
# test[322] - expected: 3.9, prediction: 4.3
# test[323] - expected: 5.6, prediction: 6.1
# test[324] - expected: 6.0, prediction: 8.4
# test[325] - expected: 4.7, prediction: 4.8
# test[326] - expected: 3.9, prediction: 3.4
# test[327] - expected: 5.0, prediction: 5.4
# test[328] - expected: 4.8, prediction: 4.0
# test[329] - expected: 4.4, prediction: 4.2
# test[330] - expected: 4.3, prediction: 4.9
# test[331] - expected: 5.3, prediction: 4.8
# test[332] - expected: 5.3, prediction: 4.2
# test[333] - expected: 4.9, prediction: 5.1
# test[334] - expected: 4.7, prediction: 5.5
# test[335] - expected: 5.2, prediction: 4.5
# test[336] - expected: 5.3, prediction: 5.2
# test[337] - expected: 4.0, prediction: 3.6
# test[338] - expected: 4.5, prediction: 4.1
# test[339] - expected: 4.8, prediction: 4.5
# test[340] - expected: 5.5, prediction: 6.9
# test[341] - expected: 5.8, prediction: 5.9
# test[342] - expected: 5.5, prediction: 5.8
# test[343] - expected: 5.8, prediction: 5.7
# test[344] - expected: 5.3, prediction: 5.1
# test[345] - expected: 4.1, prediction: 3.9
# test[346] - expected: 5.4, prediction: 4.7
# test[347] - expected: 4.3, prediction: 3.6
# test[348] - expected: 5.2, prediction: 5.1
# test[349] - expected: 5.5, prediction: 5.1
# test[350] - expected: 5.0, prediction: 4.6
# test[351] - expected: 6.1, prediction: 7.4
# test[352] - expected: 5.6, prediction: 5.9
# test[353] - expected: 4.9, prediction: 4.1
# test[354] - expected: 5.2, prediction: 6.3
# test[355] - expected: 3.8, prediction: 2.6
# test[356] - expected: 4.9, prediction: 3.1
# test[357] - expected: 4.5, prediction: 3.9
# test[358] - expected: 5.5, prediction: 3.4
# test[359] - expected: 4.9, prediction: 3.3
# test[360] - expected: 6.6, prediction: 6.4
# test[361] - expected: 5.6, prediction: 6.2
# test[362] - expected: 6.4, prediction: 6.9
# test[363] - expected: 4.8, prediction: 6.1
# test[364] - expected: 3.9, prediction: 4.8
# test[365] - expected: 4.8, prediction: 6.2
# test[366] - expected: 4.0, prediction: 3.7
# test[367] - expected: 4.1, prediction: 2.1
# test[368] - expected: 4.7, prediction: 5.4
# test[369] - expected: 6.1, prediction: 7.1
# test[370] - expected: 5.5, prediction: 3.8
# test[371] - expected: 6.1, prediction: 7.1
# test[372] - expected: 4.1, prediction: 2.5
# test[373] - expected: 4.4, prediction: 4.2
# test[374] - expected: 4.9, prediction: 5.5
# test[375] - expected: 5.6, prediction: 5.3
# test[376] - expected: 4.8, prediction: 5.5
# test[377] - expected: 4.7, prediction: 6.1
# test[378] - expected: 5.4, prediction: 5.6
# test[379] - expected: 4.7, prediction: 5.5
# test[380] - expected: 4.8, prediction: 6.4
# test[381] - expected: 4.7, prediction: 6.7
# test[382] - expected: 4.4, prediction: 4.0
# test[383] - expected: 4.8, prediction: 4.4
# test[384] - expected: 4.0, prediction: 3.8
# test[385] - expected: 5.0, prediction: 3.9
# test[386] - expected: 4.1, prediction: 3.6
# test[387] - expected: 3.7, prediction: 2.5
# test[388] - expected: 4.7, prediction: 4.6
# test[389] - expected: 4.2, prediction: 2.5
# test[390] - expected: 5.2, prediction: 6.0
# test[391] - expected: 5.1, prediction: 2.8
# test[392] - expected: 5.6, prediction: 4.5
# test[393] - expected: 5.1, prediction: 5.2
# test[394] - expected: 4.6, prediction: 5.8
# test[395] - expected: 3.8, prediction: 4.6
# test[396] - expected: 4.9, prediction: 6.5
# test[397] - expected: 5.4, prediction: 5.8
# test[398] - expected: 3.7, prediction: 4.0
# test[399] - expected: 5.4, prediction: 6.0
# test[400] - expected: 3.9, prediction: 2.9
# test[401] - expected: 4.7, prediction: 4.6
# test[402] - expected: 5.1, prediction: 4.9
# test[403] - expected: 3.9, prediction: 3.5
# test[404] - expected: 5.5, prediction: 7.9
# test[405] - expected: 4.2, prediction: 5.8
# test[406] - expected: 3.9, prediction: 3.4
# test[407] - expected: 5.1, prediction: 6.7
# test[408] - expected: 5.0, prediction: 5.6
# test[409] - expected: 4.6, prediction: 4.2
# test[410] - expected: 4.8, prediction: 4.6
# test[411] - expected: 4.5, prediction: 4.1
# test[412] - expected: 5.8, prediction: 7.2
# test[413] - expected: 5.1, prediction: 5.2
# test[414] - expected: 4.4, prediction: 4.1
# test[415] - expected: 6.1, prediction: 5.9
# test[416] - expected: 4.7, prediction: 4.6
# test[417] - expected: 5.3, prediction: 5.7
# test[418] - expected: 4.3, prediction: 5.6
# test[419] - expected: 7.0, prediction: 7.0
# test[420] - expected: 4.2, prediction: 3.5
# test[421] - expected: 5.1, prediction: 5.7
# test[422] - expected: 5.0, prediction: 3.8
# test[423] - expected: 5.5, prediction: 6.2
# test[424] - expected: 4.9, prediction: 5.8
# test[425] - expected: 3.9, prediction: 4.0
# test[426] - expected: 4.4, prediction: 6.3
# test[427] - expected: 3.9, prediction: 2.6
# test[428] - expected: 5.9, prediction: 3.8
# test[429] - expected: 5.7, prediction: 5.0
# test[430] - expected: 3.8, prediction: 5.3
# test[431] - expected: 5.8, prediction: 5.1
# test[432] - expected: 4.8, prediction: 4.9
# test[433] - expected: 5.6, prediction: 5.9
# test[434] - expected: 3.9, prediction: 3.8
# test[435] - expected: 4.3, prediction: 3.8
# test[436] - expected: 3.8, prediction: 4.2
# test[437] - expected: 4.6, prediction: 4.2
# test[438] - expected: 4.6, prediction: 4.4
# test[439] - expected: 4.0, prediction: 3.4
# test[440] - expected: 4.9, prediction: 4.3
# test[441] - expected: 4.3, prediction: 5.0
# test[442] - expected: 4.9, prediction: 6.0
# test[443] - expected: 3.8, prediction: 4.5
# test[444] - expected: 5.3, prediction: 6.2
# test[445] - expected: 6.0, prediction: 5.0
# test[446] - expected: 5.0, prediction: 6.4
# test[447] - expected: 4.9, prediction: 5.9
# test[448] - expected: 5.3, prediction: 4.3
# test[449] - expected: 5.5, prediction: 5.7
# test[450] - expected: 5.1, prediction: 4.3
# test[451] - expected: 4.6, prediction: 5.5
# test[452] - expected: 5.2, prediction: 4.7
# test[453] - expected: 5.1, prediction: 4.4
# test[454] - expected: 5.4, prediction: 5.4
# test[455] - expected: 5.4, prediction: 6.9
# test[456] - expected: 5.1, prediction: 4.9
# test[457] - expected: 6.3, prediction: 4.9
# test[458] - expected: 5.9, prediction: 6.8
# test[459] - expected: 4.2, prediction: 4.2
# test[460] - expected: 4.9, prediction: 4.2
# test[461] - expected: 5.2, prediction: 5.0
# test[462] - expected: 4.4, prediction: 3.5
# test[463] - expected: 5.3, prediction: 6.4
# test[464] - expected: 4.9, prediction: 4.1
# test[465] - expected: 5.5, prediction: 4.3
# test[466] - expected: 3.8, prediction: 3.7
# test[467] - expected: 4.8, prediction: 5.3
# test[468] - expected: 6.0, prediction: 7.0
# test[469] - expected: 5.7, prediction: 6.2
# test[470] - expected: 4.4, prediction: 5.2
# test[471] - expected: 5.0, prediction: 3.7
# test[472] - expected: 6.8, prediction: 5.5
# test[473] - expected: 5.4, prediction: 5.9
# test[474] - expected: 4.1, prediction: 3.1
# test[475] - expected: 3.8, prediction: 3.7
# test[476] - expected: 5.3, prediction: 6.1
# test[477] - expected: 3.9, prediction: 4.5
# test[478] - expected: 4.8, prediction: 4.7
# test[479] - expected: 5.4, prediction: 4.5
# test[480] - expected: 4.8, prediction: 4.6
# test[481] - expected: 4.8, prediction: 3.5
# test[482] - expected: 5.2, prediction: 4.9
# test[483] - expected: 5.8, prediction: 4.2
# test[484] - expected: 4.8, prediction: 6.1
# test[485] - expected: 4.6, prediction: 4.9
# test[486] - expected: 5.7, prediction: 5.6
# test[487] - expected: 4.5, prediction: 4.5
# test[488] - expected: 5.3, prediction: 4.4
# test[489] - expected: 3.9, prediction: 3.1
# test[490] - expected: 3.7, prediction: 2.9
# test[491] - expected: 4.1, prediction: 3.8
# test[492] - expected: 4.5, prediction: 4.8
# test[493] - expected: 4.6, prediction: 5.6
# test[494] - expected: 5.0, prediction: 3.1
# test[495] - expected: 5.3, prediction: 5.0
# test[496] - expected: 5.1, prediction: 5.5
# test[497] - expected: 5.6, prediction: 6.0
# test[498] - expected: 5.3, prediction: 6.3
# test[499] - expected: 4.2, prediction: 3.3
# test[500] - expected: 5.2, prediction: 3.8
# test[501] - expected: 5.3, prediction: 5.6
# test[502] - expected: 5.5, prediction: 3.7
# test[503] - expected: 5.0, prediction: 6.1
# test[504] - expected: 5.2, prediction: 5.4
# test[505] - expected: 5.0, prediction: 6.1
# test[506] - expected: 5.3, prediction: 5.0
# test[507] - expected: 5.7, prediction: 6.8
# test[508] - expected: 4.5, prediction: 4.7
# test[509] - expected: 5.9, prediction: 5.6
# test[510] - expected: 4.4, prediction: 4.1
# test[511] - expected: 4.0, prediction: 3.4
# test[512] - expected: 4.6, prediction: 4.2
# test[513] - expected: 3.8, prediction: 3.6
# test[514] - expected: 5.9, prediction: 6.1
# test[515] - expected: 6.5, prediction: 5.3
# test[516] - expected: 5.4, prediction: 4.0
# test[517] - expected: 3.7, prediction: 4.8
# test[518] - expected: 4.7, prediction: 3.6
# test[519] - expected: 5.0, prediction: 4.2
# test[520] - expected: 7.4, prediction: 7.6
# test[521] - expected: 3.8, prediction: 3.7
# test[522] - expected: 5.2, prediction: 5.3
# test[523] - expected: 3.8, prediction: 3.4
# test[524] - expected: 4.2, prediction: 5.3
# test[525] - expected: 4.7, prediction: 4.2
# test[526] - expected: 4.6, prediction: 3.8
# test[527] - expected: 6.5, prediction: 5.3
# test[528] - expected: 5.0, prediction: 4.8
# test[529] - expected: 4.6, prediction: 4.8
# test[530] - expected: 5.4, prediction: 5.5
# test[531] - expected: 4.5, prediction: 4.4
# test[532] - expected: 5.3, prediction: 6.0
# test[533] - expected: 5.3, prediction: 6.1
# test[534] - expected: 5.3, prediction: 4.1
# test[535] - expected: 6.1, prediction: 6.8
# test[536] - expected: 4.3, prediction: 4.2
# test[537] - expected: 6.3, prediction: 4.3
# test[538] - expected: 4.9, prediction: 6.2
# test[539] - expected: 5.2, prediction: 6.1
# test[540] - expected: 5.6, prediction: 4.5
# test[541] - expected: 5.7, prediction: 5.3
# test[542] - expected: 4.9, prediction: 5.2
# test[543] - expected: 6.5, prediction: 6.9
# test[544] - expected: 4.9, prediction: 6.5
# test[545] - expected: 3.9, prediction: 3.6
# test[546] - expected: 4.4, prediction: 4.1
# test[547] - expected: 3.7, prediction: 2.7
# test[548] - expected: 4.6, prediction: 4.7
# test[549] - expected: 4.6, prediction: 4.3
# test[550] - expected: 5.1, prediction: 4.0
# test[551] - expected: 4.5, prediction: 6.6
# test[552] - expected: 5.9, prediction: 6.0
# test[553] - expected: 5.1, prediction: 5.8
# test[554] - expected: 4.1, prediction: 2.2
# test[555] - expected: 3.9, prediction: 3.2
# test[556] - expected: 4.1, prediction: 4.7
# test[557] - expected: 5.7, prediction: 7.4
# test[558] - expected: 5.1, prediction: 5.7
# test[559] - expected: 3.9, prediction: 3.1
# test[560] - expected: 5.8, prediction: 5.7
# test[561] - expected: 5.5, prediction: 5.5
# test[562] - expected: 3.7, prediction: 2.1
# test[563] - expected: 5.1, prediction: 5.9
# test[564] - expected: 4.8, prediction: 4.4
# test[565] - expected: 5.0, prediction: 5.1
# test[566] - expected: 5.3, prediction: 4.0
# test[567] - expected: 3.9, prediction: 4.4
# test[568] - expected: 5.1, prediction: 5.6
# test[569] - expected: 5.2, prediction: 3.5
# test[570] - expected: 5.4, prediction: 4.3
# test[571] - expected: 5.3, prediction: 4.7
# test[572] - expected: 5.6, prediction: 5.3
# test[573] - expected: 5.4, prediction: 6.0
# test[574] - expected: 3.8, prediction: 4.0
# test[575] - expected: 5.1, prediction: 5.6
# test[576] - expected: 3.9, prediction: 5.7
# test[577] - expected: 4.0, prediction: 3.5
# test[578] - expected: 6.1, prediction: 5.7
# test[579] - expected: 4.0, prediction: 6.2
# test[580] - expected: 5.7, prediction: 5.5
# test[581] - expected: 5.5, prediction: 6.3
# test[582] - expected: 5.2, prediction: 3.6
# test[583] - expected: 5.3, prediction: 5.1
# test[584] - expected: 5.5, prediction: 5.1
# test[585] - expected: 5.1, prediction: 5.7
# test[586] - expected: 4.5, prediction: 3.5
# test[587] - expected: 4.9, prediction: 4.4
# test[588] - expected: 5.0, prediction: 5.2
# test[589] - expected: 5.0, prediction: 4.4
# test[590] - expected: 4.7, prediction: 4.3
# test[591] - expected: 4.9, prediction: 6.2
# test[592] - expected: 4.2, prediction: 3.8
# test[593] - expected: 4.2, prediction: 4.0
# test[594] - expected: 4.8, prediction: 4.2
# test[595] - expected: 3.9, prediction: 4.6
# test[596] - expected: 4.6, prediction: 5.9
# test[597] - expected: 5.5, prediction: 5.7
# test[598] - expected: 4.2, prediction: 4.1
# test[599] - expected: 6.4, prediction: 6.5
# test[600] - expected: 3.9, prediction: 5.0
# test[601] - expected: 5.2, prediction: 6.1
# test[602] - expected: 4.6, prediction: 4.5
# test[603] - expected: 4.4, prediction: 6.5
# test[604] - expected: 4.8, prediction: 6.0
# test[605] - expected: 5.1, prediction: 6.1
# test[606] - expected: 4.2, prediction: 4.9
# test[607] - expected: 4.8, prediction: 5.0
# test[608] - expected: 5.8, prediction: 6.9
# test[609] - expected: 5.6, prediction: 4.4
# test[610] - expected: 4.5, prediction: 6.8
# test[611] - expected: 4.7, prediction: 3.2
# test[612] - expected: 5.4, prediction: 5.9
# test[613] - expected: 5.1, prediction: 3.5
# test[614] - expected: 5.1, prediction: 6.1
# test[615] - expected: 4.6, prediction: 4.5
# test[616] - expected: 5.0, prediction: 5.0
# test[617] - expected: 4.6, prediction: 4.0
# test[618] - expected: 4.8, prediction: 5.1
# test[619] - expected: 4.7, prediction: 6.2
# test[620] - expected: 5.4, prediction: 3.2
# test[621] - expected: 5.5, prediction: 5.8
# test[622] - expected: 5.5, prediction: 4.6
# test[623] - expected: 4.8, prediction: 4.4
# test[624] - expected: 6.9, prediction: 5.3
# test[625] - expected: 5.0, prediction: 4.9
# test[626] - expected: 3.9, prediction: 3.4
# test[627] - expected: 5.4, prediction: 5.3
# test[628] - expected: 6.1, prediction: 6.8
# test[629] - expected: 5.3, prediction: 3.1
# test[630] - expected: 3.7, prediction: 4.1
# test[631] - expected: 4.1, prediction: 4.9
# test[632] - expected: 4.5, prediction: 4.4
# test[633] - expected: 4.5, prediction: 2.4
# test[634] - expected: 4.8, prediction: 5.7
# test[635] - expected: 6.0, prediction: 6.9
# test[636] - expected: 4.8, prediction: 3.2
# test[637] - expected: 5.3, prediction: 3.4
# test[638] - expected: 5.2, prediction: 6.8
# test[639] - expected: 5.5, prediction: 4.9
# test[640] - expected: 4.2, prediction: 6.8
# test[641] - expected: 5.8, prediction: 5.8
# test[642] - expected: 4.8, prediction: 5.4
# test[643] - expected: 4.1, prediction: 4.6
# test[644] - expected: 4.0, prediction: 4.9
# test[645] - expected: 5.4, prediction: 4.8
# test[646] - expected: 4.9, prediction: 2.9
# test[647] - expected: 4.8, prediction: 5.2
# test[648] - expected: 4.5, prediction: 5.6
# test[649] - expected: 5.0, prediction: 6.4
# test[650] - expected: 4.3, prediction: 2.8
# test[651] - expected: 5.8, prediction: 5.5
# test[652] - expected: 4.7, prediction: 4.9
# test[653] - expected: 4.0, prediction: 4.0
# test[654] - expected: 5.0, prediction: 5.1
# test[655] - expected: 4.7, prediction: 3.5
# test[656] - expected: 6.7, prediction: 6.3
# test[657] - expected: 5.8, prediction: 4.0
# test[658] - expected: 6.3, prediction: 6.4
# test[659] - expected: 5.4, prediction: 7.0
# test[660] - expected: 4.9, prediction: 4.8
# test[661] - expected: 5.3, prediction: 5.4
# test[662] - expected: 5.3, prediction: 5.5
# test[663] - expected: 7.3, prediction: 7.3
# test[664] - expected: 5.6, prediction: 4.5
# test[665] - expected: 5.6, prediction: 4.5
# test[666] - expected: 3.8, prediction: 3.7
# test[667] - expected: 4.9, prediction: 4.2
# test[668] - expected: 5.7, prediction: 6.8
# test[669] - expected: 4.5, prediction: 3.6
# test[670] - expected: 4.3, prediction: 3.5
# test[671] - expected: 5.3, prediction: 5.0
# test[672] - expected: 5.9, prediction: 4.6
# test[673] - expected: 5.0, prediction: 5.1
# test[674] - expected: 5.1, prediction: 4.2
# test[675] - expected: 5.2, prediction: 5.1
# test[676] - expected: 4.9, prediction: 6.1
# test[677] - expected: 5.0, prediction: 6.3
# test[678] - expected: 3.7, prediction: 4.4
# test[679] - expected: 5.4, prediction: 6.6
# test[680] - expected: 4.6, prediction: 4.2
# test[681] - expected: 3.6, prediction: 3.3
# test[682] - expected: 5.0, prediction: 5.5
# test[683] - expected: 4.9, prediction: 4.1
# test[684] - expected: 5.3, prediction: 5.9
# test[685] - expected: 4.8, prediction: 4.3
# test[686] - expected: 6.1, prediction: 6.2
# test[687] - expected: 5.7, prediction: 4.8
# test[688] - expected: 4.9, prediction: 3.8
# test[689] - expected: 4.5, prediction: 3.7
# test[690] - expected: 4.7, prediction: 5.2
# test[691] - expected: 6.1, prediction: 5.8
# test[692] - expected: 4.5, prediction: 5.0
# test[693] - expected: 5.3, prediction: 4.6
# test[694] - expected: 3.9, prediction: 2.7
# test[695] - expected: 6.0, prediction: 6.1
# test[696] - expected: 5.1, prediction: 4.8
# test[697] - expected: 4.8, prediction: 4.9
# test[698] - expected: 3.8, prediction: 3.7
# test[699] - expected: 4.4, prediction: 2.2
# test[700] - expected: 5.7, prediction: 6.0
# test[701] - expected: 6.0, prediction: 7.3
# test[702] - expected: 4.2, prediction: 4.6
# test[703] - expected: 5.3, prediction: 5.0
# test[704] - expected: 4.0, prediction: 3.1
# test[705] - expected: 5.7, prediction: 5.2
# test[706] - expected: 4.4, prediction: 4.2
# test[707] - expected: 5.7, prediction: 7.3
# test[708] - expected: 5.4, prediction: 6.3
# test[709] - expected: 6.4, prediction: 5.9
# test[710] - expected: 5.2, prediction: 4.9
# test[711] - expected: 4.7, prediction: 5.4
# test[712] - expected: 4.1, prediction: 5.1
# test[713] - expected: 3.7, prediction: 3.3
# test[714] - expected: 4.9, prediction: 6.3
# test[715] - expected: 4.3, prediction: 3.8
# test[716] - expected: 5.4, prediction: 5.6
# test[717] - expected: 3.8, prediction: 3.1
# test[718] - expected: 3.9, prediction: 4.1
# test[719] - expected: 5.3, prediction: 6.4
# test[720] - expected: 3.9, prediction: 3.6
# test[721] - expected: 4.0, prediction: 5.5
# test[722] - expected: 4.5, prediction: 6.0
# test[723] - expected: 4.2, prediction: 4.0
# test[724] - expected: 4.5, prediction: 3.6
# test[725] - expected: 4.8, prediction: 4.2
# test[726] - expected: 5.5, prediction: 5.2
# test[727] - expected: 4.1, prediction: 4.5
# test[728] - expected: 5.3, prediction: 4.0
# test[729] - expected: 4.0, prediction: 3.1
# test[730] - expected: 5.1, prediction: 4.4
# test[731] - expected: 4.3, prediction: 5.9
# test[732] - expected: 5.2, prediction: 5.9
# test[733] - expected: 4.3, prediction: 3.9
# test[734] - expected: 4.2, prediction: 3.7
# test[735] - expected: 5.6, prediction: 6.3
# test[736] - expected: 6.0, prediction: 5.5
# test[737] - expected: 5.1, prediction: 4.4
# test[738] - expected: 5.7, prediction: 5.2
# test[739] - expected: 5.6, prediction: 5.5
# test[740] - expected: 3.9, prediction: 1.9
# test[741] - expected: 4.9, prediction: 7.1
# test[742] - expected: 5.0, prediction: 5.5
# test[743] - expected: 4.4, prediction: 4.5
# test[744] - expected: 4.5, prediction: 5.1
# test[745] - expected: 5.5, prediction: 7.2
# test[746] - expected: 5.1, prediction: 5.5
# test[747] - expected: 5.5, prediction: 6.2
# test[748] - expected: 4.9, prediction: 4.8
# test[749] - expected: 4.6, prediction: 5.5
# test[750] - expected: 6.4, prediction: 6.5
# test[751] - expected: 5.3, prediction: 5.1
# test[752] - expected: 5.9, prediction: 4.4
# test[753] - expected: 4.7, prediction: 5.2
# test[754] - expected: 4.6, prediction: 4.6
# test[755] - expected: 4.2, prediction: 4.2
# test[756] - expected: 6.4, prediction: 5.3
# test[757] - expected: 5.3, prediction: 4.5
# test[758] - expected: 5.2, prediction: 5.5
# test[759] - expected: 5.5, prediction: 4.7
# test[760] - expected: 4.2, prediction: 4.8
# test[761] - expected: 3.9, prediction: 4.4
# test[762] - expected: 5.6, prediction: 5.5
# test[763] - expected: 4.2, prediction: 5.4
# test[764] - expected: 3.8, prediction: 2.3
# test[765] - expected: 5.8, prediction: 5.0
# test[766] - expected: 6.1, prediction: 7.6
# test[767] - expected: 5.5, prediction: 6.5
# test[768] - expected: 3.8, prediction: 5.7
# test[769] - expected: 4.3, prediction: 3.9
# test[770] - expected: 4.0, prediction: 4.5
# test[771] - expected: 4.0, prediction: 2.9
# test[772] - expected: 5.8, prediction: 6.6
# test[773] - expected: 4.2, prediction: 4.9
# test[774] - expected: 5.3, prediction: 5.8
# test[775] - expected: 4.1, prediction: 4.4
# test[776] - expected: 5.4, prediction: 7.1
# test[777] - expected: 5.3, prediction: 7.2
# test[778] - expected: 5.3, prediction: 6.0
# test[779] - expected: 6.1, prediction: 7.7
# test[780] - expected: 5.1, prediction: 6.0
# test[781] - expected: 4.9, prediction: 6.7
# test[782] - expected: 5.3, prediction: 5.1
# test[783] - expected: 5.0, prediction: 5.9
# test[784] - expected: 3.9, prediction: 6.3
# test[785] - expected: 5.5, prediction: 5.3
# test[786] - expected: 4.5, prediction: 3.4
# test[787] - expected: 5.4, prediction: 4.6
# test[788] - expected: 4.1, prediction: 3.2
# test[789] - expected: 4.7, prediction: 6.7
# test[790] - expected: 4.2, prediction: 3.8
# test[791] - expected: 6.5, prediction: 6.7
# test[792] - expected: 6.0, prediction: 5.0
# test[793] - expected: 5.4, prediction: 5.4
# test[794] - expected: 4.4, prediction: 4.9
# test[795] - expected: 5.0, prediction: 5.8
# test[796] - expected: 4.5, prediction: 5.1
# test[797] - expected: 4.3, prediction: 4.8
# test[798] - expected: 5.2, prediction: 4.2
# test[799] - expected: 4.6, prediction: 4.4
# test[800] - expected: 5.0, prediction: 6.1
# test[801] - expected: 5.5, prediction: 5.6
# test[802] - expected: 5.7, prediction: 7.1
# test[803] - expected: 4.0, prediction: 4.4
# test[804] - expected: 5.7, prediction: 6.1
# test[805] - expected: 5.2, prediction: 6.5
# test[806] - expected: 5.9, prediction: 5.6
# test[807] - expected: 3.7, prediction: 2.2
# test[808] - expected: 5.8, prediction: 7.3
# test[809] - expected: 5.3, prediction: 4.3
# test[810] - expected: 5.2, prediction: 5.7
# test[811] - expected: 4.4, prediction: 4.1
# test[812] - expected: 4.9, prediction: 5.6
# test[813] - expected: 4.1, prediction: 3.3
# test[814] - expected: 3.3, prediction: 2.9
# test[815] - expected: 5.3, prediction: 5.1
# test[816] - expected: 5.2, prediction: 4.1
# test[817] - expected: 4.0, prediction: 2.4
# test[818] - expected: 5.4, prediction: 5.5
# test[819] - expected: 5.7, prediction: 6.6
# test[820] - expected: 5.7, prediction: 5.1
# test[821] - expected: 4.6, prediction: 5.6
# test[822] - expected: 5.2, prediction: 6.0
# test[823] - expected: 6.6, prediction: 7.6
# test[824] - expected: 5.7, prediction: 4.7
# test[825] - expected: 4.0, prediction: 2.7
# test[826] - expected: 5.1, prediction: 6.2
# test[827] - expected: 5.6, prediction: 5.0
# test[828] - expected: 4.2, prediction: 3.7
# test[829] - expected: 5.1, prediction: 4.0
# test[830] - expected: 3.9, prediction: 3.9
# test[831] - expected: 5.0, prediction: 3.6
# test[832] - expected: 5.8, prediction: 6.1
# test[833] - expected: 5.3, prediction: 4.5
# test[834] - expected: 3.8, prediction: 4.6
# test[835] - expected: 5.4, prediction: 6.2
# test[836] - expected: 6.2, prediction: 5.3
# test[837] - expected: 3.8, prediction: 4.4
# test[838] - expected: 5.5, prediction: 6.5
# test[839] - expected: 4.7, prediction: 4.5
# test[840] - expected: 4.4, prediction: 4.0
# test[841] - expected: 5.1, prediction: 4.7
# test[842] - expected: 5.1, prediction: 4.5
# test[843] - expected: 4.1, prediction: 6.1
# test[844] - expected: 5.3, prediction: 7.9
# test[845] - expected: 5.5, prediction: 5.8
# test[846] - expected: 5.7, prediction: 3.2
# test[847] - expected: 5.7, prediction: 7.6
# test[848] - expected: 4.2, prediction: 2.8
# test[849] - expected: 4.9, prediction: 3.6
# test[850] - expected: 4.4, prediction: 3.1
# test[851] - expected: 3.9, prediction: 2.8
# test[852] - expected: 4.9, prediction: 5.6
# test[853] - expected: 4.9, prediction: 5.2
# test[854] - expected: 5.5, prediction: 3.2
# test[855] - expected: 5.2, prediction: 5.3
# test[856] - expected: 4.2, prediction: 3.6
# test[857] - expected: 6.0, prediction: 6.1
# test[858] - expected: 5.0, prediction: 5.7
# test[859] - expected: 5.0, prediction: 5.0
# test[860] - expected: 5.0, prediction: 5.7
# test[861] - expected: 6.0, prediction: 4.8
# test[862] - expected: 3.8, prediction: 3.9
# test[863] - expected: 4.2, prediction: 4.5
# test[864] - expected: 5.3, prediction: 5.8
# test[865] - expected: 4.2, prediction: 5.0
# test[866] - expected: 5.1, prediction: 4.9
# test[867] - expected: 3.9, prediction: 2.4
# test[868] - expected: 4.8, prediction: 5.0
# test[869] - expected: 5.5, prediction: 7.0
# test[870] - expected: 4.0, prediction: 2.4
# test[871] - expected: 4.5, prediction: 2.5
# test[872] - expected: 5.8, prediction: 7.0
# test[873] - expected: 4.3, prediction: 3.7
# test[874] - expected: 5.2, prediction: 6.0
# test[875] - expected: 4.5, prediction: 4.9
# test[876] - expected: 4.2, prediction: 1.9
# test[877] - expected: 7.4, prediction: 6.1
# test[878] - expected: 4.8, prediction: 5.9
# test[879] - expected: 4.5, prediction: 4.8
# test[880] - expected: 5.5, prediction: 5.7
# test[881] - expected: 4.0, prediction: 3.8
# test[882] - expected: 4.3, prediction: 2.7
# test[883] - expected: 4.1, prediction: 3.7
# test[884] - expected: 4.7, prediction: 6.4
# test[885] - expected: 5.4, prediction: 6.4
# test[886] - expected: 4.3, prediction: 4.3
# test[887] - expected: 4.8, prediction: 5.8
# test[888] - expected: 4.9, prediction: 4.8
# test[889] - expected: 5.1, prediction: 4.5
# test[890] - expected: 6.6, prediction: 6.4
# test[891] - expected: 3.8, prediction: 4.2
# test[892] - expected: 4.3, prediction: 3.4
# test[893] - expected: 4.8, prediction: 4.3
# test[894] - expected: 5.1, prediction: 4.0
# test[895] - expected: 4.2, prediction: 4.3
# test[896] - expected: 5.5, prediction: 3.8
# test[897] - expected: 6.0, prediction: 6.7
# test[898] - expected: 4.5, prediction: 5.8
# test[899] - expected: 4.8, prediction: 6.3
# test[900] - expected: 5.5, prediction: 7.0
# Summary of Differences:
# Less than one: 628
# Less than two: 235
# Less than three: 37
# Unmanageable: 1

# %%
print("Test Samples Accounted for: {}/{}".format(
    less_than_one+less_than_two+less_than_three+not_manageable,
    len(valence_y_test)))

acc1 = less_than_one/len(valence_y_test)
acc2 = (less_than_one+less_than_two)/len(valence_y_test)
acc3 = (less_than_one+less_than_two+less_than_three)/len(valence_y_test)

print("Taking into consideration predictions off by decimals: {0:} / {1:} = {2:.6f}".format(
    less_than_one,len(valence_y_test),acc1))
print("If we include predictions off by 1._: {0:} / {1:} = {2:.6f}".format(
    less_than_one+less_than_two, 
    len(valence_y_test),
    acc2))
print("If we include predictions off by 2._: {0:} / {1:} = {2:.6f}".format(
    less_than_one+less_than_two+less_than_three,
    len(valence_y_test),
    acc3))
# Out:
# Test Samples Accounted for: 901/901
# Taking into consideration predictions off by decimals: 628 / 901 = 0.697003
# If we include predictions off by 1._: 863 / 901 = 0.957825
# If we include predictions off by 2._: 900 / 901 = 0.998890

# %%
# Saving, Loading and Testing Models
valence_regressor = build_model()
valence_regressor.fit(x_train, valence_y_train, epochs=EPOCHS,
                     validation_split=0.2, verbose=0,
                     callbacks=[early_stop, PrintDot()])
valence_regressor.save('audio_nn_valence_regressor.model')
# loaded_valence_model = tf.keras.models.load_model('audio_nn_valence_regressor.model')
# valence_predictions = loaded_valence_model.predict(x_test)
# Out:
# .........................................
